# %% [markdown]
# <a href="https://colab.research.google.com/github/DinaZakaria/Credit-Card-Segmentation/blob/master/ML2_Project_V04.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 0. Imports

# %%
# !pip install scikit-learn-extra
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting scikit-learn-extra
#   Downloading scikit_learn_extra-0.2.0-cp37-cp37m-manylinux2010_x86_64.whl (1.7 MB)
#      |████████████████████████████████| 1.7 MB 4.7 MB/s
# Requirement already satisfied: scikit-learn>=0.23.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn-extra) (1.0.2)
# Requirement already satisfied: numpy>=1.13.3 in /usr/local/lib/python3.7/dist-packages (from scikit-learn-extra) (1.21.6)
# Requirement already satisfied: scipy>=0.19.1 in /usr/local/lib/python3.7/dist-packages (from scikit-learn-extra) (1.4.1)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=0.23.0->scikit-learn-extra) (1.1.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=0.23.0->scikit-learn-extra) (3.1.0)
# Installing collected packages: scikit-learn-extra
# Successfully installed scikit-learn-extra-0.2.0

# %%
from google.colab import drive
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler, RobustScaler, MinMaxScaler, normalize
from sklearn.cluster import KMeans, AgglomerativeClustering, DBSCAN
from sklearn.metrics import silhouette_score
from sklearn.decomposition import PCA, KernelPCA
from sklearn_extra.cluster import KMedoids
import scipy.cluster.hierarchy as shc
from scipy.spatial import distance 
from sklearn.neighbors import NearestNeighbors
from sklearn.manifold import TSNE
from sklearn.ensemble import IsolationForest
from sklearn.mixture import GaussianMixture
from sklearn.model_selection import train_test_split

# %% [markdown]
# ## 01. Github Clonning

# %%
# !git clone https://github.com/DinaZakaria/Credit-Card-Segmentation.git
# Out:
# fatal: destination path 'Credit-Card-Segmentation' already exists and is not an empty directory.

# %%
# read path of data csv file 
CC_data  = pd.read_csv("Credit-Card-Segmentation/CC GENERAL.csv")

# %% [markdown]
# # 1. EDA and Data Preprocessing

# %% [markdown]
# > ## 1.1. Explore Data

# %%
CC_data.head(10)
# Out:
#   CUST_ID      BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0  C10001    40.900749           0.818182      95.40              0.00
# 1  C10002  3202.467416           0.909091       0.00              0.00
# 2  C10003  2495.148862           1.000000     773.17            773.17
# 3  C10004  1666.670542           0.636364    1499.00           1499.00
# 4  C10005   817.714335           1.000000      16.00             16.00
# 5  C10006  1809.828751           1.000000    1333.28              0.00
# 6  C10007   627.260806           1.000000    7091.01           6402.63
# 7  C10008  1823.652743           1.000000     436.20              0.00
# 8  C10009  1014.926473           1.000000     861.49            661.49
# 9  C10010   152.225975           0.545455    1281.60           1281.60
#
#    INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                   95.40      0.000000             0.166667
# 1                    0.00   6442.945483             0.000000
# 2                    0.00      0.000000             1.000000
# 3                    0.00    205.788017             0.083333
# 4                    0.00      0.000000             0.083333
# 5                 1333.28      0.000000             0.666667
# 6                  688.38      0.000000             1.000000
# 7                  436.20      0.000000             1.000000
# 8                  200.00      0.000000             0.333333
# 9                    0.00      0.000000             0.166667
#
#    ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# 0                    0.000000                          0.083333
# 1                    0.000000                          0.000000
# 2                    1.000000                          0.000000
# 3                    0.083333                          0.000000
# 4                    0.083333                          0.000000
# 5                    0.000000                          0.583333
# 6                    1.000000                          1.000000
# 7                    0.000000                          1.000000
# 8                    0.083333                          0.250000
# 9                    0.166667                          0.000000
#
#    CASH_ADVANCE_FREQUENCY  CASH_ADVANCE_TRX  PURCHASES_TRX  CREDIT_LIMIT  \
# 0                0.000000                 0              2        1000.0
# 1                0.250000                 4              0        7000.0
# 2                0.000000                 0             12        7500.0
# 3                0.083333                 1              1        7500.0
# 4                0.000000                 0              1        1200.0
# 5                0.000000                 0              8        1800.0
# 6                0.000000                 0             64       13500.0
# 7                0.000000                 0             12        2300.0
# 8                0.000000                 0              5        7000.0
# 9                0.000000                 0              3       11000.0
#
#       PAYMENTS  MINIMUM_PAYMENTS  PRC_FULL_PAYMENT  TENURE
# 0   201.802084        139.509787          0.000000      12
# 1  4103.032597       1072.340217          0.222222      12
# 2   622.066742        627.284787          0.000000      12
# 3     0.000000               NaN          0.000000      12
# 4   678.334763        244.791237          0.000000      12
# 5  1400.057770       2407.246035          0.000000      12
# 6  6354.314328        198.065894          1.000000      12
# 7   679.065082        532.033990          0.000000      12
# 8   688.278568        311.963409          0.000000      12
# 9  1164.770591        100.302262          0.000000      12

# %%
# Data types
CC_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8950 entries, 0 to 8949
# Data columns (total 18 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   CUST_ID                           8950 non-null   object
#  1   BALANCE                           8950 non-null   float64
#  2   BALANCE_FREQUENCY                 8950 non-null   float64
#  3   PURCHASES                         8950 non-null   float64
#  4   ONEOFF_PURCHASES                  8950 non-null   float64
#  5   INSTALLMENTS_PURCHASES            8950 non-null   float64
#  6   CASH_ADVANCE                      8950 non-null   float64
#  7   PURCHASES_FREQUENCY               8950 non-null   float64
#  8   ONEOFF_PURCHASES_FREQUENCY        8950 non-null   float64
#  9   PURCHASES_INSTALLMENTS_FREQUENCY  8950 non-null   float64
#  10  CASH_ADVANCE_FREQUENCY            8950 non-null   float64
#  11  CASH_ADVANCE_TRX                  8950 non-null   int64
#  12  PURCHASES_TRX                     8950 non-null   int64
#  13  CREDIT_LIMIT                      8949 non-null   float64
#  14  PAYMENTS                          8950 non-null   float64
#  15  MINIMUM_PAYMENTS                  8637 non-null   float64
#  16  PRC_FULL_PAYMENT                  8950 non-null   float64
#  17  TENURE                            8950 non-null   int64
# dtypes: float64(14), int64(3), object(1)
# memory usage: 1.2+ MB

# %%
# basic statitics for numerical columns
CC_data.describe()
# Out:
#             BALANCE  BALANCE_FREQUENCY     PURCHASES  ONEOFF_PURCHASES  \
# count   8950.000000        8950.000000   8950.000000       8950.000000
# mean    1564.474828           0.877271   1003.204834        592.437371
# std     2081.531879           0.236904   2136.634782       1659.887917
# min        0.000000           0.000000      0.000000          0.000000
# 25%      128.281915           0.888889     39.635000          0.000000
# 50%      873.385231           1.000000    361.280000         38.000000
# 75%     2054.140036           1.000000   1110.130000        577.405000
# max    19043.138560           1.000000  49039.570000      40761.250000
#
#        INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# count             8950.000000   8950.000000          8950.000000
# mean               411.067645    978.871112             0.490351
# std                904.338115   2097.163877             0.401371
# min                  0.000000      0.000000             0.000000
# 25%                  0.000000      0.000000             0.083333
# 50%                 89.000000      0.000000             0.500000
# 75%                468.637500   1113.821139             0.916667
# max              22500.000000  47137.211760             1.000000
#
#        ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# count                 8950.000000                       8950.000000
# mean                     0.202458                          0.364437
# std                      0.298336                          0.397448
# min                      0.000000                          0.000000
# 25%                      0.000000                          0.000000
# 50%                      0.083333                          0.166667
# 75%                      0.300000                          0.750000
# max                      1.000000                          1.000000
#
#        CASH_ADVANCE_FREQUENCY  CASH_ADVANCE_TRX  PURCHASES_TRX  CREDIT_LIMIT  \
# count             8950.000000       8950.000000    8950.000000   8949.000000
# mean                 0.135144          3.248827      14.709832   4494.449450
# std                  0.200121          6.824647      24.857649   3638.815725
# min                  0.000000          0.000000       0.000000     50.000000
# 25%                  0.000000          0.000000       1.000000   1600.000000
# 50%                  0.000000          0.000000       7.000000   3000.000000
# 75%                  0.222222          4.000000      17.000000   6500.000000
# max                  1.500000        123.000000     358.000000  30000.000000
#
#            PAYMENTS  MINIMUM_PAYMENTS  PRC_FULL_PAYMENT       TENURE
# count   8950.000000       8637.000000       8950.000000  8950.000000
# mean    1733.143852        864.206542          0.153715    11.517318
# std     2895.063757       2372.446607          0.292499     1.338331
# min        0.000000          0.019163          0.000000     6.000000
# 25%      383.276166        169.123707          0.000000    12.000000
# 50%      856.901546        312.343947          0.000000    12.000000
# 75%     1901.134317        825.485459          0.142857    12.000000
# max    50721.483360      76406.207520          1.000000    12.000000

# %%
# Check for null values
CC_data.isnull().sum().sort_values(ascending=False)
# Out:
# MINIMUM_PAYMENTS                    313
# CREDIT_LIMIT                          1
# CUST_ID                               0
# BALANCE                               0
# PRC_FULL_PAYMENT                      0
# PAYMENTS                              0
# PURCHASES_TRX                         0
# CASH_ADVANCE_TRX                      0
# CASH_ADVANCE_FREQUENCY                0
# PURCHASES_INSTALLMENTS_FREQUENCY      0
# ONEOFF_PURCHASES_FREQUENCY            0
# PURCHASES_FREQUENCY                   0
# CASH_ADVANCE                          0
# INSTALLMENTS_PURCHASES                0
# ONEOFF_PURCHASES                      0
# PURCHASES                             0
# BALANCE_FREQUENCY                     0
# TENURE                                0
# dtype: int64

# %%
CC_data.isna().sum()
# Out:
# CUST_ID                               0
# BALANCE                               0
# BALANCE_FREQUENCY                     0
# PURCHASES                             0
# ONEOFF_PURCHASES                      0
# INSTALLMENTS_PURCHASES                0
# CASH_ADVANCE                          0
# PURCHASES_FREQUENCY                   0
# ONEOFF_PURCHASES_FREQUENCY            0
# PURCHASES_INSTALLMENTS_FREQUENCY      0
# CASH_ADVANCE_FREQUENCY                0
# CASH_ADVANCE_TRX                      0
# PURCHASES_TRX                         0
# CREDIT_LIMIT                          1
# PAYMENTS                              0
# MINIMUM_PAYMENTS                    313
# PRC_FULL_PAYMENT                      0
# TENURE                                0
# dtype: int64

# %% [markdown]
# MINIMUM_PAYMENTS contains 313 null values and CREDIT_LIMIT contains 1 null value

# %%
# Check for duplicates 
CC_data.duplicated().sum()
# Out:
# 0

# %% [markdown]
# There is no duplicates

# %%
# Check for skewness
CC_data.skew(skipna = True)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
# BALANCE                              2.393386
# BALANCE_FREQUENCY                   -2.023266
# PURCHASES                            8.144269
# ONEOFF_PURCHASES                    10.045083
# INSTALLMENTS_PURCHASES               7.299120
# CASH_ADVANCE                         5.166609
# PURCHASES_FREQUENCY                  0.060164
# ONEOFF_PURCHASES_FREQUENCY           1.535613
# PURCHASES_INSTALLMENTS_FREQUENCY     0.509201
# CASH_ADVANCE_FREQUENCY               1.828686
# CASH_ADVANCE_TRX                     5.721298
# PURCHASES_TRX                        4.630655
# CREDIT_LIMIT                         1.522464
# PAYMENTS                             5.907620
# MINIMUM_PAYMENTS                    13.622797
# PRC_FULL_PAYMENT                     1.942820
# TENURE                              -2.943017
# dtype: float64

# %% [markdown]
# > ### 1.1.1. Data Visualization

# %%
# exclude object column 
vis_col = CC_data.select_dtypes(exclude=['object']).columns.to_list()
vis_col
# Out:
# ['BALANCE',
#  'BALANCE_FREQUENCY',
#  'PURCHASES',
#  'ONEOFF_PURCHASES',
#  'INSTALLMENTS_PURCHASES',
#  'CASH_ADVANCE',
#  'PURCHASES_FREQUENCY',
#  'ONEOFF_PURCHASES_FREQUENCY',
#  'PURCHASES_INSTALLMENTS_FREQUENCY',
#  'CASH_ADVANCE_FREQUENCY',
#  'CASH_ADVANCE_TRX',
#  'PURCHASES_TRX',
#  'CREDIT_LIMIT',
#  'PAYMENTS',
#  'MINIMUM_PAYMENTS',
#  'PRC_FULL_PAYMENT',
#  'TENURE']

# %%
# Histogram 
CC_data[vis_col].hist(bins=15, figsize=(20, 15), layout=(5, 4));

# %%
# Check for data skewness
CC_data.skew(skipna = True)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
# BALANCE                              2.393386
# BALANCE_FREQUENCY                   -2.023266
# PURCHASES                            8.144269
# ONEOFF_PURCHASES                    10.045083
# INSTALLMENTS_PURCHASES               7.299120
# CASH_ADVANCE                         5.166609
# PURCHASES_FREQUENCY                  0.060164
# ONEOFF_PURCHASES_FREQUENCY           1.535613
# PURCHASES_INSTALLMENTS_FREQUENCY     0.509201
# CASH_ADVANCE_FREQUENCY               1.828686
# CASH_ADVANCE_TRX                     5.721298
# PURCHASES_TRX                        4.630655
# CREDIT_LIMIT                         1.522464
# PAYMENTS                             5.907620
# MINIMUM_PAYMENTS                    13.622797
# PRC_FULL_PAYMENT                     1.942820
# TENURE                              -2.943017
# dtype: float64

# %% [markdown]
# > ## 1.2. Data Preprocessing

# %% [markdown]
# >> ### 1.2.1. Remove Nulls

# %%
CC_data.dropna(inplace = True)

# %%
# reset index 
CC_data.reset_index(drop = True, inplace=True)

# %%
# Checkf for df
CC_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8636 entries, 0 to 8635
# Data columns (total 18 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   CUST_ID                           8636 non-null   object
#  1   BALANCE                           8636 non-null   float64
#  2   BALANCE_FREQUENCY                 8636 non-null   float64
#  3   PURCHASES                         8636 non-null   float64
#  4   ONEOFF_PURCHASES                  8636 non-null   float64
#  5   INSTALLMENTS_PURCHASES            8636 non-null   float64
#  6   CASH_ADVANCE                      8636 non-null   float64
#  7   PURCHASES_FREQUENCY               8636 non-null   float64
#  8   ONEOFF_PURCHASES_FREQUENCY        8636 non-null   float64
#  9   PURCHASES_INSTALLMENTS_FREQUENCY  8636 non-null   float64
#  10  CASH_ADVANCE_FREQUENCY            8636 non-null   float64
#  11  CASH_ADVANCE_TRX                  8636 non-null   int64
#  12  PURCHASES_TRX                     8636 non-null   int64
#  13  CREDIT_LIMIT                      8636 non-null   float64
#  14  PAYMENTS                          8636 non-null   float64
#  15  MINIMUM_PAYMENTS                  8636 non-null   float64
#  16  PRC_FULL_PAYMENT                  8636 non-null   float64
#  17  TENURE                            8636 non-null   int64
# dtypes: float64(14), int64(3), object(1)
# memory usage: 1.2+ MB

# %%
# check for no null values
CC_data.isnull().sum().sort_values(ascending=False)
# Out:
# CUST_ID                             0
# BALANCE                             0
# PRC_FULL_PAYMENT                    0
# MINIMUM_PAYMENTS                    0
# PAYMENTS                            0
# CREDIT_LIMIT                        0
# PURCHASES_TRX                       0
# CASH_ADVANCE_TRX                    0
# CASH_ADVANCE_FREQUENCY              0
# PURCHASES_INSTALLMENTS_FREQUENCY    0
# ONEOFF_PURCHASES_FREQUENCY          0
# PURCHASES_FREQUENCY                 0
# CASH_ADVANCE                        0
# INSTALLMENTS_PURCHASES              0
# ONEOFF_PURCHASES                    0
# PURCHASES                           0
# BALANCE_FREQUENCY                   0
# TENURE                              0
# dtype: int64

# %% [markdown]
# Since we don't need CUST_ID in our clustering so we can remove it

# %%
CC_data.drop('CUST_ID', axis = 1, inplace = True)

# %%
# check for columns 
CC_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8636 entries, 0 to 8635
# Data columns (total 17 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   BALANCE                           8636 non-null   float64
#  1   BALANCE_FREQUENCY                 8636 non-null   float64
#  2   PURCHASES                         8636 non-null   float64
#  3   ONEOFF_PURCHASES                  8636 non-null   float64
#  4   INSTALLMENTS_PURCHASES            8636 non-null   float64
#  5   CASH_ADVANCE                      8636 non-null   float64
#  6   PURCHASES_FREQUENCY               8636 non-null   float64
#  7   ONEOFF_PURCHASES_FREQUENCY        8636 non-null   float64
#  8   PURCHASES_INSTALLMENTS_FREQUENCY  8636 non-null   float64
#  9   CASH_ADVANCE_FREQUENCY            8636 non-null   float64
#  10  CASH_ADVANCE_TRX                  8636 non-null   int64
#  11  PURCHASES_TRX                     8636 non-null   int64
#  12  CREDIT_LIMIT                      8636 non-null   float64
#  13  PAYMENTS                          8636 non-null   float64
#  14  MINIMUM_PAYMENTS                  8636 non-null   float64
#  15  PRC_FULL_PAYMENT                  8636 non-null   float64
#  16  TENURE                            8636 non-null   int64
# dtypes: float64(14), int64(3)
# memory usage: 1.1 MB

# %% [markdown]
# > ### 1.1.2. Heat Map

# %%
plt.figure(figsize=(20,20))
corr_data = CC_data.corr()
sns.heatmap(corr_data,annot=True)
plt.show()

# %% [markdown]
# # Scenario 1

# %% [markdown]
# # 2. Data Preparation for Model

# %% [markdown]
# > ## 2.1. Data Splitting

# %%
CC_df, cc_df_test = train_test_split(CC_data, test_size=0.2, random_state=1)

# %% [markdown]
# > ## 2.2.  Scaling and Transform

# %% [markdown]
# >>>### 2.2.1. LogTransform

# %%
CC_df_log = CC_df.copy()
columns = CC_df_log.columns
for col in columns:
  CC_df_log [col] = np.log(CC_df_log[col]+1)

# %%
CC_df_log.describe().T
# Out:
#                                    count      mean       std       min  \
# BALANCE                           6908.0  6.265135  1.892816  0.000000
# BALANCE_FREQUENCY                 6908.0  0.631944  0.126268  0.000000
# PURCHASES                         6908.0  4.915222  2.930826  0.000000
# ONEOFF_PURCHASES                  6908.0  3.245228  3.249118  0.000000
# INSTALLMENTS_PURCHASES            6908.0  3.367032  3.095139  0.000000
# CASH_ADVANCE                      6908.0  3.378322  3.574130  0.000000
# PURCHASES_FREQUENCY               6908.0  0.362595  0.277490  0.000000
# ONEOFF_PURCHASES_FREQUENCY        6908.0  0.160627  0.216962  0.000000
# PURCHASES_INSTALLMENTS_FREQUENCY  6908.0  0.270864  0.282062  0.000000
# CASH_ADVANCE_FREQUENCY            6908.0  0.116043  0.158147  0.000000
# CASH_ADVANCE_TRX                  6908.0  0.834527  1.016455  0.000000
# PURCHASES_TRX                     6908.0  1.905264  1.379952  0.000000
# CREDIT_LIMIT                      6908.0  8.100607  0.822155  3.931826
# PAYMENTS                          6908.0  6.815881  1.166011  0.048326
# MINIMUM_PAYMENTS                  6908.0  5.921001  1.192385  0.018982
# PRC_FULL_PAYMENT                  6908.0  0.123262  0.214123  0.000000
# TENURE                            6908.0  2.520701  0.129022  1.945910
#
#                                        25%       50%       75%        max
# BALANCE                           5.020926  6.814217  7.657024   9.854515
# BALANCE_FREQUENCY                 0.646627  0.693147  0.693147   0.693147
# PURCHASES                         3.651690  5.929523  7.041641  10.800403
# ONEOFF_PURCHASES                  0.000000  3.833509  6.381816  10.615512
# INSTALLMENTS_PURCHASES            0.000000  4.506895  6.189418  10.021315
# CASH_ADVANCE                      0.000000  0.000000  7.053224  10.284766
# PURCHASES_FREQUENCY               0.080042  0.405465  0.650588   0.693147
# ONEOFF_PURCHASES_FREQUENCY        0.000000  0.080042  0.287682   0.693147
# PURCHASES_INSTALLMENTS_FREQUENCY  0.000000  0.154151  0.559616   0.693147
# CASH_ADVANCE_FREQUENCY            0.000000  0.000000  0.223144   0.916291
# CASH_ADVANCE_TRX                  0.000000  0.000000  1.609438   4.820282
# PURCHASES_TRX                     0.693147  2.079442  2.890372   5.883322
# CREDIT_LIMIT                      7.438972  8.006701  8.779711  10.308986
# PAYMENTS                          6.036239  6.811839  7.578472  10.834125
# MINIMUM_PAYMENTS                  5.134571  5.737756  6.704530  11.243832
# PRC_FULL_PAYMENT                  0.000000  0.000000  0.154151   0.693147
# TENURE                            2.564949  2.564949  2.564949   2.564949

# %% [markdown]
# >>> #### 1.2.2.2. StandardScaler -> scaling to unit variance

# %%
CC_df_std = CC_df.copy()
columns = CC_df_std.columns
features = CC_df_std[columns]
CC_df_std[columns] = StandardScaler().fit_transform(features.values)

# %%
CC_df_std.describe().T
# Out:
#                                    count          mean       std       min  \
# BALANCE                           6908.0 -1.110866e-16  1.000072 -0.762899
# BALANCE_FREQUENCY                 6908.0  2.674307e-17  1.000072 -4.307755
# PURCHASES                         6908.0 -2.160017e-17  1.000072 -0.465606
# ONEOFF_PURCHASES                  6908.0 -5.142898e-17  1.000072 -0.351703
# INSTALLMENTS_PURCHASES            6908.0 -9.257216e-18  1.000072 -0.455811
# CASH_ADVANCE                      6908.0 -1.645727e-17  1.000072 -0.486851
# PURCHASES_FREQUENCY               6908.0  1.202152e-16  1.000072 -1.226317
# ONEOFF_PURCHASES_FREQUENCY        6908.0 -3.317169e-17  1.000072 -0.685543
# PURCHASES_INSTALLMENTS_FREQUENCY  6908.0  2.365733e-17  1.000072 -0.919423
# CASH_ADVANCE_FREQUENCY            6908.0 -3.240026e-17  1.000072 -0.683697
# CASH_ADVANCE_TRX                  6908.0 -5.142898e-18  1.000072 -0.478877
# PURCHASES_TRX                     6908.0  3.317169e-17  1.000072 -0.586926
# CREDIT_LIMIT                      6908.0  2.108588e-17  1.000072 -1.227518
# PAYMENTS                          6908.0  2.468591e-17  1.000072 -0.614483
# MINIMUM_PAYMENTS                  6908.0  1.388582e-17  1.000072 -0.347431
# PRC_FULL_PAYMENT                  6908.0  3.754315e-17  1.000072 -0.542843
# TENURE                            6908.0  5.749760e-16  1.000072 -4.177016
#
#                                        25%       50%       75%        max
# BALANCE                          -0.691134 -0.329262  0.245018   8.314570
# BALANCE_FREQUENCY                 0.068102  0.505688  0.505688   0.505688
# PURCHASES                        -0.448552 -0.295264  0.053297  21.811908
# ONEOFF_PURCHASES                 -0.351703 -0.325377 -0.008253  23.376172
# INSTALLMENTS_PURCHASES           -0.455811 -0.358768  0.070934  23.902307
# CASH_ADVANCE                     -0.486851 -0.486851  0.078969  13.850856
# PURCHASES_FREQUENCY              -1.018751  0.019085  1.056920   1.264486
# ONEOFF_PURCHASES_FREQUENCY       -0.685543 -0.406627  0.430124   2.661461
# PURCHASES_INSTALLMENTS_FREQUENCY -0.919423 -0.500237  0.966913   1.595691
# CASH_ADVANCE_FREQUENCY           -0.683697 -0.683697  0.552341   6.732530
# CASH_ADVANCE_TRX                 -0.478877 -0.478877  0.094224  17.143978
# PURCHASES_TRX                    -0.547770 -0.312834  0.078726  13.430909
# CREDIT_LIMIT                     -0.774505 -0.417585  0.543353   6.995366
# PAYMENTS                         -0.471512 -0.303543  0.055232  16.764553
# MINIMUM_PAYMENTS                 -0.280745 -0.225200 -0.025376  29.842442
# PRC_FULL_PAYMENT                 -0.542843 -0.542843  0.020175   2.835255
# TENURE                            0.356580  0.356580  0.356580   0.356580

# %%
# Histogram 
CC_df_std[columns].hist(bins=15, figsize=(20, 15), layout=(5, 4))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fed018d9490>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fed013b6d10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fed013080d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fed012c05d0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fed012f6ad0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fed012a2b90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fed0126f510>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fed01227a10>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fed01231b50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fed011f4150>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fed01159950>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fed0110ee50>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fed010d2390>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fed01089890>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fed0103dd90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fed010002d0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fed010377d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fed00fefcd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fed00fb2210>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fed00f68710>]],
#       dtype=object)

# %% [markdown]
# >>> #### 1.2.2.3. RobustScaler -> standardization to a unit value of a robust variance estimator

# %%
CC_df_robust = CC_df.copy()
columns = CC_df_robust.columns
features = CC_df_robust[columns]
CC_df_robust[columns] = RobustScaler().fit_transform(features.values)

# %%
CC_df_robust.describe().T
# Out:
#                                    count      mean       std        min  \
# BALANCE                           6908.0  0.351719  1.068281  -0.463212
# BALANCE_FREQUENCY                 6908.0 -1.155632  2.285434 -11.000011
# PURCHASES                         6908.0  0.588351  1.992775  -0.339429
# ONEOFF_PURCHASES                  6908.0  0.947378  2.911844  -0.076653
# INSTALLMENTS_PURCHASES            6908.0  0.681104  1.898592  -0.184231
# CASH_ADVANCE                      6908.0  0.860434  1.767474   0.000000
# PURCHASES_FREQUENCY               6908.0 -0.009194  0.481807  -0.600000
# ONEOFF_PURCHASES_FREQUENCY        6908.0  0.364470  0.896390  -0.249999
# PURCHASES_INSTALLMENTS_FREQUENCY  6908.0  0.265190  0.530167  -0.222223
# CASH_ADVANCE_FREQUENCY            6908.0  0.553136  0.809095   0.000000
# CASH_ADVANCE_TRX                  6908.0  0.835589  1.745020   0.000000
# PURCHASES_TRX                     6908.0  0.499340  1.596296  -0.437500
# CREDIT_LIMIT                      6908.0  0.316866  0.758862  -0.614583
# PAYMENTS                          6908.0  0.576264  1.898595  -0.590306
# MINIMUM_PAYMENTS                  6908.0  0.881862  3.916180  -0.478643
# PRC_FULL_PAYMENT                  6908.0  0.964167  1.776273   0.000000
# TENURE                            6908.0 -0.471917  1.323549  -6.000000
#
#                                        25%           50%       75%         max
# BALANCE                          -0.386553  2.894820e-17  0.613447    9.233370
# BALANCE_FREQUENCY                -1.000000  0.000000e+00  0.000000    0.000000
# PURCHASES                        -0.305448 -2.572947e-17  0.694552   44.051420
# ONEOFF_PURCHASES                 -0.076653  0.000000e+00  0.923347   69.010212
# INSTALLMENTS_PURCHASES           -0.184231  0.000000e+00  0.815769   46.058543
# CASH_ADVANCE                      0.000000  0.000000e+00  1.000000   25.339697
# PURCHASES_FREQUENCY              -0.500000  0.000000e+00  0.500000    0.600000
# ONEOFF_PURCHASES_FREQUENCY       -0.249999  0.000000e+00  0.750001    2.750004
# PURCHASES_INSTALLMENTS_FREQUENCY -0.222223  0.000000e+00  0.777777    1.111111
# CASH_ADVANCE_FREQUENCY            0.000000  0.000000e+00  1.000000    6.000000
# CASH_ADVANCE_TRX                  0.000000  0.000000e+00  1.000000   30.750000
# PURCHASES_TRX                    -0.375000  0.000000e+00  0.625000   21.937500
# CREDIT_LIMIT                     -0.270833  0.000000e+00  0.729167    5.625000
# PAYMENTS                         -0.318881  3.697558e-17  0.681119   32.403048
# MINIMUM_PAYMENTS                 -0.217508  0.000000e+00  0.782492  117.741779
# PRC_FULL_PAYMENT                  0.000000  0.000000e+00  1.000000    5.999988
# TENURE                            0.000000  0.000000e+00  0.000000    0.000000

# %%
# Histogram 
CC_df_robust[columns].hist(bins=15, figsize=(20, 15), layout=(5, 4))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fed018f1e10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fed0199bfd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fed0230d910>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fed01a3d6d0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fed022b8510>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fed017bbed0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fed01af9fd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fed0196fa10>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fed019b5590>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fed02364c10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fed0add76d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fed09f72b50>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fed08c59390>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fed0b452d50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fed08923a50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fed041f0650>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fed0882b810>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fed08a52d10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fed09022850>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fed0bfd0ad0>]],
#       dtype=object)

# %% [markdown]
# >>> #### 1.2.2.4. MinMaxScaler ->  standardization to [0, 1]-range

# %%
CC_df_minmax = CC_df.copy()
columns = CC_df_minmax.columns
features = CC_df_minmax[columns]
CC_df_minmax[columns] = MinMaxScaler().fit_transform(features.values)

# %%
CC_df_minmax.describe().T
# Out:
#                                    count      mean       std  min       25%  \
# BALANCE                           6908.0  0.084043  0.110171  0.0  0.007906
# BALANCE_FREQUENCY                 6908.0  0.894943  0.207767  0.0  0.909091
# PURCHASES                         6908.0  0.020900  0.044892  0.0  0.000766
# ONEOFF_PURCHASES                  6908.0  0.014822  0.042148  0.0  0.000000
# INSTALLMENTS_PURCHASES            6908.0  0.018713  0.041057  0.0  0.000000
# CASH_ADVANCE                      6908.0  0.033956  0.069751  0.0  0.000000
# PURCHASES_FREQUENCY               6908.0  0.492338  0.401506  0.0  0.083333
# ONEOFF_PURCHASES_FREQUENCY        6908.0  0.204823  0.298796  0.0  0.000000
# PURCHASES_INSTALLMENTS_FREQUENCY  6908.0  0.365559  0.397625  0.0  0.000000
# CASH_ADVANCE_FREQUENCY            6908.0  0.092189  0.134849  0.0  0.000000
# CASH_ADVANCE_TRX                  6908.0  0.027174  0.056749  0.0  0.000000
# PURCHASES_TRX                     6908.0  0.041870  0.071343  0.0  0.002793
# CREDIT_LIMIT                      6908.0  0.149281  0.121621  0.0  0.055092
# PAYMENTS                          6908.0  0.035358  0.057545  0.0  0.008227
# MINIMUM_PAYMENTS                  6908.0  0.011508  0.033126  0.0  0.002209
# PRC_FULL_PAYMENT                  6908.0  0.160695  0.296046  0.0  0.000000
# TENURE                            6908.0  0.921347  0.220591  0.0  1.000000
#
#                                        50%       75%  max
# BALANCE                           0.047771  0.111035  1.0
# BALANCE_FREQUENCY                 1.000000  1.000000  1.0
# PURCHASES                         0.007646  0.023293  1.0
# ONEOFF_PURCHASES                  0.001110  0.014475  1.0
# INSTALLMENTS_PURCHASES            0.003984  0.021625  1.0
# CASH_ADVANCE                      0.000000  0.039464  1.0
# PURCHASES_FREQUENCY               0.500000  0.916667  1.0
# ONEOFF_PURCHASES_FREQUENCY        0.083333  0.333333  1.0
# PURCHASES_INSTALLMENTS_FREQUENCY  0.166667  0.750000  1.0
# CASH_ADVANCE_FREQUENCY            0.000000  0.166667  1.0
# CASH_ADVANCE_TRX                  0.000000  0.032520  1.0
# PURCHASES_TRX                     0.019553  0.047486  1.0
# CREDIT_LIMIT                      0.098497  0.215359  1.0
# PAYMENTS                          0.017892  0.038536  1.0
# MINIMUM_PAYMENTS                  0.004049  0.010668  1.0
# PRC_FULL_PAYMENT                  0.000000  0.166667  1.0
# TENURE                            1.000000  1.000000  1.0

# %%
# Histogram 
CC_df_minmax[columns].hist(bins=15, figsize=(20, 15), layout=(5, 4))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fed09a77e50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fed025095d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fed0b445d50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fed024c5e50>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fed0b58ebd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fed017b0a90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fed009954d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fed04ffd9d0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fed0500ab10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fed0190a110>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fed02430910>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fed0209ae10>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fed02216350>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fed0521f850>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fed0a20dd50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fed015c8290>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fed01b4f790>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fed054b4c90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fed052a61d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fed091366d0>]],
#       dtype=object)

# %% [markdown]
# # 3. Different Clustering Techniques

# %% [markdown]
# > ## 3.1. KMeans Clustering

# %% [markdown]
# >> ### 3.1.1. Get Optimal number of clustering K

# %% [markdown]
# >>> #### 3.1.1.1. Using Silhoutte method to get optimumal

# %%
def K_sil_method(df):
  K = range(2,10)
  silhouette_avg = []
  opt_k = 0
  sil_k = {}
  for k in K:
    # initialise kmeans
    kmeanModel = KMeans(n_clusters=k)
    kmeanModel.fit(df)
    cluster_labels=kmeanModel.labels_
    #print(cluster_labels)
    # silhouette score
    sil_score = silhouette_score(df, cluster_labels)
    silhouette_avg.append(sil_score)
    sil_k[k] = sil_score
  plt.plot(K, silhouette_avg, 'bx-')
  plt.xlabel('Values of K') 
  plt.ylabel('Silhouette score') 
  plt.title('Silhouette analysis For Optimal k')
  plt.show()
  for key, value in sil_k.items(): 
         if max(silhouette_avg) == value: 
             opt_k = key
        
  # choose the optimum K
  return opt_k

# %%
opt_k_sil = K_sil_method(CC_df_std)

# %%
print("The optimal K using silhoutte score: ", opt_k_sil)
# Out:
# The optimal K using silhoutte score:  3

# %% [markdown]
# >>> #### 3.1.1.2. Using Elbow method to get optimumal K

# %%
def elbow_method(df):
  distortions = []
  K = range(1,10)
  opt_k = 0
  for k in K:
      kmeanModel = KMeans(n_clusters=k)
      kmeanModel.fit(df)
      distortions.append((kmeanModel.inertia_)/k)
      cluster_labels = kmeanModel.labels_
  #print(len(distortions)-1)
  for i in range (1, len(distortions)-1):
   # print(i)
    if (distortions[i]-distortions[i+1])/(distortions[i-1]-distortions[i]) > 0.5:
      opt_k = i
   #   print(opt_k)
      break
  #print(distortions)
  plt.figure(figsize=(16,8))
  plt.plot(K, distortions, 'bx-')
  plt.xlabel('k')
  plt.ylabel('Distortion')
  plt.title('The Elbow Method showing the optimal k')
  plt.show()
  return opt_k

# %%
opt_k_elbow = elbow_method(CC_df_std)

# %%
print("The optimal K using elbow method: ", opt_k_elbow)
# Out:
# The optimal K using elbow method:  3

# %% [markdown]
# >> ### 3.1.2. Applying Kmean Clustering using optimal K

# %%
def Kmeans_plot (df, k):
  plt.rcParams['figure.figsize'] =(25,40)
  for num in range(0,17):
      ax = plt.subplot(5,4,num+1)
      col = df.columns[num]
      sns.stripplot(df['constant'],df[col], ax=ax, hue=df['label'])
      plt.xlabel('constant')

  plt.show()

# %%
CC_df_k = CC_df.copy()
kmeanModel = KMeans(n_clusters=opt_k_elbow)
kmeanModel.fit_predict(CC_df_std)
labels = kmeanModel.labels_
CC_df_k['clusters'] = labels

# %%
CC_df_k
# Out:
#           BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0       40.900749           0.818182      95.40              0.00
# 1     3202.467416           0.909091       0.00              0.00
# 2     2495.148862           1.000000     773.17            773.17
# 3      817.714335           1.000000      16.00             16.00
# 4     1809.828751           1.000000    1333.28              0.00
# ...           ...                ...        ...               ...
# 8631     5.871712           0.500000      20.90             20.90
# 8632    28.493517           1.000000     291.12              0.00
# 8633    23.398673           0.833333     144.40              0.00
# 8634    13.457564           0.833333       0.00              0.00
# 8635   372.708075           0.666667    1093.25           1093.25
#
#       INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                      95.40      0.000000             0.166667
# 1                       0.00   6442.945483             0.000000
# 2                       0.00      0.000000             1.000000
# 3                       0.00      0.000000             0.083333
# 4                    1333.28      0.000000             0.666667
# ...                      ...           ...                  ...
# 8631                    0.00      0.000000             0.166667
# 8632                  291.12      0.000000             1.000000
# 8633                  144.40      0.000000             0.833333
# 8634                    0.00     36.558778             0.000000
# 8635                    0.00    127.040008             0.666667
#
#       ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# 0                       0.000000                          0.083333
# 1                       0.000000                          0.000000
# 2                       1.000000                          0.000000
# 3                       0.083333                          0.000000
# 4                       0.000000                          0.583333
# ...                          ...                               ...
# 8631                    0.166667                          0.000000
# 8632                    0.000000                          0.833333
# 8633                    0.000000                          0.666667
# 8634                    0.000000                          0.000000
# 8635                    0.666667                          0.000000
#
#       CASH_ADVANCE_FREQUENCY  CASH_ADVANCE_TRX  PURCHASES_TRX  CREDIT_LIMIT  \
# 0                   0.000000                 0              2        1000.0
# 1                   0.250000                 4              0        7000.0
# 2                   0.000000                 0             12        7500.0
# 3                   0.000000                 0              1        1200.0
# 4                   0.000000                 0              8        1800.0
# ...                      ...               ...            ...           ...
# 8631                0.000000                 0              1         500.0
# 8632                0.000000                 0              6        1000.0
# 8633                0.000000                 0              5        1000.0
# 8634                0.166667                 2              0         500.0
# 8635                0.333333                 2             23        1200.0
#
#          PAYMENTS  MINIMUM_PAYMENTS  PRC_FULL_PAYMENT  TENURE  clusters
# 0      201.802084        139.509787          0.000000      12         1
# 1     4103.032597       1072.340217          0.222222      12         2
# 2      622.066742        627.284787          0.000000      12         1
# 3      678.334763        244.791237          0.000000      12         1
# 4     1400.057770       2407.246035          0.000000      12         1
# ...           ...               ...               ...     ...       ...
# 8631    58.644883         43.473717          0.000000       6         1
# 8632   325.594462         48.886365          0.500000       6         1
# 8633    81.270775         82.418369          0.250000       6         1
# 8634    52.549959         55.755628          0.250000       6         1
# 8635    63.165404         88.288956          0.000000       6         1
#
# [8636 rows x 18 columns]

# %%
# CC_df_minmax_label = CC_df_minmax.copy()
# Kmeans_plot(CC_df_minmax_label, opt_k_sil)

# %%
for c in CC_df_k:
    grid= sns.FacetGrid(CC_df_k, col='clusters')
    grid.map(plt.hist, c)

# %%
silhouette_score(CC_df_std, CC_df_k['clusters'], metric='euclidean')
# Out:
# 0.24754638153191033

# %% [markdown]
# >> ### 3.1.3. KMeans Clustering using PCA

# %%
CC_df_std_nor = normalize(CC_df_std)
pca = PCA(n_components = 2).fit(CC_df_std_nor)
df_pca  = pca.fit_transform(CC_df_std_nor)

# %%
pca_df = pd.DataFrame(df_pca, columns = ["PCA1", "PCA2"])
pca_df
# Out:
#           PCA1      PCA2
# 0    -0.481788 -0.692991
# 1    -0.537375  0.527808
# 2     0.320760  0.265224
# 3    -0.562994 -0.503868
# 4     0.320512 -0.254468
# ...        ...       ...
# 8631 -0.214325 -0.267827
# 8632  0.320251 -0.195203
# 8633  0.183536 -0.245043
# 8634 -0.307306 -0.176105
# 8635  0.008882  0.091170
#
# [8636 rows x 2 columns]

# %%
pca_df.shape
#columns.shape
# Out:
# (8636, 2)

# %%
kmeanModel = KMeans(n_clusters=opt_k_elbow)
labels = kmeanModel.fit_predict(pca_df)
plt.scatter(pca_df['PCA1'], pca_df['PCA2'],
            c = labels) 
plt.show()

# %%
silhouette_score(pca_df, labels, metric='euclidean')
# Out:
# 0.4547195643253931

# %% [markdown]
# >> ### 3.1.4. KMeans Clustering using KernelPCA

# %%
CC_df_std_nor = normalize(CC_df_std)
Kpca = KernelPCA(n_components = 2, kernel = 'rbf').fit(CC_df_std_nor)
df_Kpca  = Kpca.fit_transform(CC_df_std_nor)

# %%
Kpca_df = pd.DataFrame(df_Kpca, columns = ["PCA1", "PCA2"])
Kpca_df
# Out:
#           PCA1      PCA2
# 0    -0.158098 -0.226071
# 1    -0.172392  0.172719
# 2     0.104427  0.086621
# 3    -0.185598 -0.164991
# 4     0.105177 -0.082704
# ...        ...       ...
# 8631 -0.068386 -0.086018
# 8632  0.104202 -0.062359
# 8633  0.060031 -0.078151
# 8634 -0.098268 -0.055736
# 8635  0.003478  0.029934
#
# [8636 rows x 2 columns]

# %%
Kpca_df.shape
#columns.shape
# Out:
# (8636, 2)

# %%
kmeanModel = KMeans(n_clusters=opt_k_elbow)
labels = kmeanModel.fit_predict(Kpca_df)
plt.scatter(Kpca_df['PCA1'], Kpca_df['PCA2'],
            c = labels) 
plt.show()

# %%
silhouette_score(Kpca_df, labels, metric='euclidean')
# Out:
# 0.4550216765594345

# %% [markdown]
# >> ### 3.1.5. KMeans Clustering using TSNE

# %%
CC_df_std_nor = normalize(CC_df_std)
tsne = TSNE(n_components=2, verbose=1, perplexity=40, n_iter=300)
df_tsne = tsne.fit_transform(CC_df_std_nor)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/manifold/_t_sne.py:783: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/manifold/_t_sne.py:793: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   FutureWarning,
# [t-SNE] Computing 121 nearest neighbors...
# [t-SNE] Indexed 8636 samples in 0.000s...
# [t-SNE] Computed neighbors for 8636 samples in 1.960s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 8636
# [t-SNE] Computed conditional probabilities for sample 2000 / 8636
# [t-SNE] Computed conditional probabilities for sample 3000 / 8636
# [t-SNE] Computed conditional probabilities for sample 4000 / 8636
# [t-SNE] Computed conditional probabilities for sample 5000 / 8636
# [t-SNE] Computed conditional probabilities for sample 6000 / 8636
# [t-SNE] Computed conditional probabilities for sample 7000 / 8636
# [t-SNE] Computed conditional probabilities for sample 8000 / 8636
# [t-SNE] Computed conditional probabilities for sample 8636 / 8636
# [t-SNE] Mean sigma: 0.161981
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 81.012314
# [t-SNE] KL divergence after 300 iterations: 2.461266

# %%
tsne_df = pd.DataFrame(df_tsne, columns = ["TSNE1", "TSNE2"])
tsne_df
# Out:
#          TSNE1     TSNE2
# 0     3.089990 -7.509646
# 1    -6.175225  0.877236
# 2    -1.731684  4.255822
# 3     0.164092 -3.375106
# 4     2.793423  1.619134
# ...        ...       ...
# 8631  1.155401 -7.145128
# 8632  5.161213 -2.758548
# 8633  4.571025 -3.356423
# 8634 -0.206279 -7.457432
# 8635  0.805862 -5.855492
#
# [8636 rows x 2 columns]

# %%
kmeansModel = KMeans(n_clusters=3)
labels = kmeansModel.fit_predict(tsne_df)
plt.scatter(tsne_df['TSNE1'], tsne_df['TSNE2'],
            c = labels) 
plt.show()

# %% [markdown]
# > ## 3.2. KMediods Clustering

# %% [markdown]
# >> ### 3.2.1. Get Optimal number of clustering K

# %% [markdown]
# >>> #### 3.2.1.1. Using Silhoutte method to get optimal K

# %%
def K_sil_method(df):
  K = range(2,10)
  silhouette_avg = []
  opt_k = 0
  sil_k = {}
  for k in K:
    # initialise kmeans
    kmediodModel = KMedoids(n_clusters=k)
    kmediodModel.fit(df)
    cluster_labels=kmediodModel.labels_
    #print(cluster_labels)
    # silhouette score
    sil_score = silhouette_score(df, cluster_labels)
    silhouette_avg.append(sil_score)
    sil_k[k] = sil_score
  plt.plot(K, silhouette_avg, 'bx-')
  plt.xlabel('Values of K') 
  plt.ylabel('Silhouette score') 
  plt.title('Silhouette analysis For Optimal k')
  plt.show()
  for key, value in sil_k.items(): 
         if max(silhouette_avg) == value: 
             opt_k = key
        
  # choose the optimum K
  return opt_k

# %%
opt_k_sil = K_sil_method(CC_df_std)

# %%
print("The optimal K using silhoutte score: ", opt_k_sil)
# Out:
# The optimal K using silhoutte score:  2

# %%
def elbow_method(df):
  distortions = []
  K = range(1,10)
  opt_k = 0
  for k in K:
      kmediodModel = KMedoids(n_clusters=k)
      kmediodModel.fit(df)
      cluster_labels=kmediodModel.labels_      
      distortions.append((kmeanModel.inertia_)/k)
  #print(len(distortions)-1)
  for i in range (1, len(distortions)-1):
   # print(i)
    if (distortions[i]-distortions[i+1])/(distortions[i-1]-distortions[i]) > 0.5:
      opt_k = i
   #   print(opt_k)
      break
  #print(distortions)
  plt.figure(figsize=(16,8))
  plt.plot(K, distortions, 'bx-')
  plt.xlabel('k')
  plt.ylabel('Distortion')
  plt.title('The Elbow Method showing the optimal k')
  plt.show()
  return opt_k

# %%
opt_k_elbow = elbow_method(CC_df_std)

# %%
print("The optimal K using elbow method: ", opt_k_elbow)
# Out:
# The optimal K using elbow method:  3

# %% [markdown]
# >> ### 3.2.2. Applying KMediods Clustering using optimal K

# %%
CC_df_k = CC_df.copy()
kmediodModel = KMedoids(n_clusters=opt_k_elbow)
kmediodModel.fit(CC_df_std)
cluster_labels=kmediodModel.labels_
labels = kmeanModel.labels_
CC_df_k['clusters'] = labels

# %%
CC_df_k
# Out:
#           BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0       40.900749           0.818182      95.40              0.00
# 1     3202.467416           0.909091       0.00              0.00
# 2     2495.148862           1.000000     773.17            773.17
# 3      817.714335           1.000000      16.00             16.00
# 4     1809.828751           1.000000    1333.28              0.00
# ...           ...                ...        ...               ...
# 8631     5.871712           0.500000      20.90             20.90
# 8632    28.493517           1.000000     291.12              0.00
# 8633    23.398673           0.833333     144.40              0.00
# 8634    13.457564           0.833333       0.00              0.00
# 8635   372.708075           0.666667    1093.25           1093.25
#
#       INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                      95.40      0.000000             0.166667
# 1                       0.00   6442.945483             0.000000
# 2                       0.00      0.000000             1.000000
# 3                       0.00      0.000000             0.083333
# 4                    1333.28      0.000000             0.666667
# ...                      ...           ...                  ...
# 8631                    0.00      0.000000             0.166667
# 8632                  291.12      0.000000             1.000000
# 8633                  144.40      0.000000             0.833333
# 8634                    0.00     36.558778             0.000000
# 8635                    0.00    127.040008             0.666667
#
#       ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# 0                       0.000000                          0.083333
# 1                       0.000000                          0.000000
# 2                       1.000000                          0.000000
# 3                       0.083333                          0.000000
# 4                       0.000000                          0.583333
# ...                          ...                               ...
# 8631                    0.166667                          0.000000
# 8632                    0.000000                          0.833333
# 8633                    0.000000                          0.666667
# 8634                    0.000000                          0.000000
# 8635                    0.666667                          0.000000
#
#       CASH_ADVANCE_FREQUENCY  CASH_ADVANCE_TRX  PURCHASES_TRX  CREDIT_LIMIT  \
# 0                   0.000000                 0              2        1000.0
# 1                   0.250000                 4              0        7000.0
# 2                   0.000000                 0             12        7500.0
# 3                   0.000000                 0              1        1200.0
# 4                   0.000000                 0              8        1800.0
# ...                      ...               ...            ...           ...
# 8631                0.000000                 0              1         500.0
# 8632                0.000000                 0              6        1000.0
# 8633                0.000000                 0              5        1000.0
# 8634                0.166667                 2              0         500.0
# 8635                0.333333                 2             23        1200.0
#
#          PAYMENTS  MINIMUM_PAYMENTS  PRC_FULL_PAYMENT  TENURE  clusters
# 0      201.802084        139.509787          0.000000      12         0
# 1     4103.032597       1072.340217          0.222222      12         2
# 2      622.066742        627.284787          0.000000      12         1
# 3      678.334763        244.791237          0.000000      12         0
# 4     1400.057770       2407.246035          0.000000      12         1
# ...           ...               ...               ...     ...       ...
# 8631    58.644883         43.473717          0.000000       6         0
# 8632   325.594462         48.886365          0.500000       6         1
# 8633    81.270775         82.418369          0.250000       6         1
# 8634    52.549959         55.755628          0.250000       6         0
# 8635    63.165404         88.288956          0.000000       6         1
#
# [8636 rows x 18 columns]

# %%
for c in CC_df_k:
    grid= sns.FacetGrid(CC_df_k, col='clusters')
    grid.map(plt.hist, c)

# %%
silhouette_score(CC_df_std, CC_df_k['clusters'], metric='euclidean')
# Out:
# 0.15146192527871521

# %% [markdown]
# >> ### 3.2.3. KMediods Clustering using PCA

# %%
CC_df_std_nor = normalize(CC_df_std)
pca = PCA(n_components = 2).fit(CC_df_std_nor)
df_pca  = pca.fit_transform(CC_df_std_nor)

# %%
pca_df = pd.DataFrame(df_pca, columns = ["PCA1", "PCA2"])
pca_df
# Out:
#           PCA1      PCA2
# 0    -0.481788 -0.692991
# 1    -0.537375  0.527808
# 2     0.320760  0.265223
# 3    -0.562994 -0.503868
# 4     0.320512 -0.254471
# ...        ...       ...
# 8631 -0.214325 -0.267827
# 8632  0.320251 -0.195203
# 8633  0.183536 -0.245043
# 8634 -0.307306 -0.176105
# 8635  0.008883  0.091170
#
# [8636 rows x 2 columns]

# %%
pca_df.shape
#columns.shape
# Out:
# (8636, 2)

# %%
kmediodModel = KMedoids(n_clusters=opt_k_elbow)
labels = kmediodModel.fit_predict(pca_df)
plt.scatter(pca_df['PCA1'], pca_df['PCA2'],
            c = labels) 
plt.show()

# %%
silhouette_score(pca_df, labels, metric='euclidean')
# Out:
# 0.4504935145152485

# %% [markdown]
# >> ### 3.2.4. KMediods Clustering using KernelPCA

# %%
CC_df_std_nor = normalize(CC_df_std)
Kpca = KernelPCA(n_components = 2, kernel = 'rbf').fit(CC_df_std_nor)
df_Kpca  = Kpca.fit_transform(CC_df_std_nor)

# %%
Kpca_df = pd.DataFrame(df_Kpca, columns = ["PCA1", "PCA2"])
Kpca_df
# Out:
#           PCA1      PCA2
# 0    -0.158098 -0.226071
# 1    -0.172392  0.172719
# 2     0.104427  0.086621
# 3    -0.185598 -0.164991
# 4     0.105177 -0.082704
# ...        ...       ...
# 8631 -0.068386 -0.086018
# 8632  0.104202 -0.062359
# 8633  0.060031 -0.078151
# 8634 -0.098268 -0.055736
# 8635  0.003478  0.029934
#
# [8636 rows x 2 columns]

# %%
Kpca_df.shape
#columns.shape
# Out:
# (8636, 2)

# %%
kmediodModel = KMedoids(n_clusters=opt_k_elbow)
labels = kmediodModel.fit_predict(Kpca_df)
plt.scatter(Kpca_df['PCA1'], Kpca_df['PCA2'],
            c = labels) 
plt.show()

# %%
silhouette_score(Kpca_df, labels, metric='euclidean')
# Out:
# 0.451372957612939

# %% [markdown]
# >> ### 3.1.5. KMediods Clustering using TSNE

# %%
CC_df_std_nor = normalize(CC_df_std)
tsne = TSNE(n_components=2, verbose=1, perplexity=40, n_iter=300)
df_tsne = tsne.fit_transform(CC_df_std_nor)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/manifold/_t_sne.py:783: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/manifold/_t_sne.py:793: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   FutureWarning,
# [t-SNE] Computing 121 nearest neighbors...
# [t-SNE] Indexed 8636 samples in 0.000s...
# [t-SNE] Computed neighbors for 8636 samples in 1.942s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 8636
# [t-SNE] Computed conditional probabilities for sample 2000 / 8636
# [t-SNE] Computed conditional probabilities for sample 3000 / 8636
# [t-SNE] Computed conditional probabilities for sample 4000 / 8636
# [t-SNE] Computed conditional probabilities for sample 5000 / 8636
# [t-SNE] Computed conditional probabilities for sample 6000 / 8636
# [t-SNE] Computed conditional probabilities for sample 7000 / 8636
# [t-SNE] Computed conditional probabilities for sample 8000 / 8636
# [t-SNE] Computed conditional probabilities for sample 8636 / 8636
# [t-SNE] Mean sigma: 0.161981
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 80.978790
# [t-SNE] KL divergence after 300 iterations: 2.421181

# %%
tsne_df = pd.DataFrame(df_tsne, columns = ["TSNE1", "TSNE2"])
tsne_df
# Out:
#          TSNE1      TSNE2
# 0     2.470503   3.961300
# 1    -1.296013   4.869562
# 2     0.162464  -0.898593
# 3    -7.990682  -3.982497
# 4    -2.679890  -8.914809
# ...        ...        ...
# 8631  3.996859   9.180352
# 8632  8.300158   7.254403
# 8633  7.490649   7.627518
# 8634  2.345029  10.556466
# 8635  3.260776   9.411744
#
# [8636 rows x 2 columns]

# %%
kMediodModel = KMedoids(n_clusters=3)
labels = kMediodModel.fit_predict(tsne_df)
plt.scatter(tsne_df['TSNE1'], tsne_df['TSNE2'],
            c = labels) 
plt.show()

# %%
silhouette_score(tsne_df, labels, metric='euclidean')

# %% [markdown]
# > ## 3.3. Hierarchical methods

# %% [markdown]
# >> ### 3.3.1. Choosing metric and method using pdist

# %%
links = ['ward', 'complete', 'average', 'single', 'weighted', 'centroid', 'median']
metrics = ['braycurtis', 'canberra', 'chebyshev', 'cityblock', 'correlation',
        'cosine', 'dice', 'euclidean', 'hamming', 'jaccard',
        'kulsinski', 'mahalanobis', 'matching', 'minkowski', 'rogerstanimoto',
        'russellrao', 'seuclidean', 'sokalmichener', 'sokalsneath', 'sqeuclidean']

# %%
columns = CC_df_std.columns
met_lin = {}
for metric in metrics:
  for link in links:
    if link == 'ward' and metric != 'euclidean':
            pass
    elif link == 'centroid' and metric != 'euclidean':
        pass
    elif link == 'median' and metric != 'euclidean':
        pass
    else:
      Z = shc.linkage(CC_df_std[columns], metric = metric, method = link)
      c, cop_dist = shc.cophenet(Z, distance.pdist(CC_df_std[columns]))
      if c > 0.8:
        key = metric + " + " + link
        met_lin [key] = c
        print("Metric: "+metric + " and Link: "+link+ " correlation score: "+str(c))
# Out:
# Metric: chebyshev and Link: complete correlation score: 0.8292055097753697
# Metric: chebyshev and Link: average correlation score: 0.8704793472940504
# Metric: chebyshev and Link: single correlation score: 0.8448357374035694
# Metric: chebyshev and Link: weighted correlation score: 0.8052587349459928
# Metric: cityblock and Link: average correlation score: 0.8305781964840179
# /usr/local/lib/python3.7/dist-packages/scipy/cluster/hierarchy.py:1699: RuntimeWarning: invalid value encountered in double_scalars
#   c = numerator.sum() / np.sqrt((denomA.sum() * denomB.sum()))
# Metric: euclidean and Link: complete correlation score: 0.8201186937921817
# Metric: euclidean and Link: average correlation score: 0.8810566943599851
# Metric: euclidean and Link: single correlation score: 0.8439715406337083
# Metric: euclidean and Link: centroid correlation score: 0.8732883923310477
# Metric: minkowski and Link: complete correlation score: 0.8201186937921817
# Metric: minkowski and Link: average correlation score: 0.881056694359985
# Metric: minkowski and Link: single correlation score: 0.8439715406337082
# Metric: seuclidean and Link: complete correlation score: 0.820118693792184
# Metric: seuclidean and Link: average correlation score: 0.881056694359987
# Metric: seuclidean and Link: single correlation score: 0.8439715406337124
# Metric: sqeuclidean and Link: average correlation score: 0.8037717787416976

# %%
max(met_lin.values())
met_lin.values()
# Out:
# dict_values([0.8292055097753697, 0.8704793472940504, 0.8448357374035694, 0.8052587349459928, 0.8305781964840179, 0.8201186937921817, 0.8810566943599851, 0.8439715406337083, 0.8732883923310477, 0.8201186937921817, 0.881056694359985, 0.8439715406337082, 0.820118693792184, 0.881056694359987, 0.8439715406337124, 0.8037717787416976])

# %%
for key, value in met_lin.items(): 
    if  value == max(met_lin.values()): 
        bestMethod=key
        break 
print("Best Method is:" + key + " with score: "+str(value))
# Out:
# Best Method is:seuclidean + average with score: 0.881056694359987

# %% [markdown]
# >> ### 3.3.2. Choosing optimal K

# %% [markdown]
# >>> #### 3.3.2.1. Choosing number of clusters using Dendrogram

# %%
plt.figure(figsize=(10, 7))
plt.title("Dendrogram")
dend = shc.dendrogram(shc.linkage(y=CC_df_std , method='average', metric='euclidean'))

# %% [markdown]
# >>> #### 3.3.2.2. Choosing number of clusters using Silhoutte score

# %%
def K_sil_agg_method(df):
  K = range(2,10)
  silhouette_avg = []
  opt_k = 0
  sil_k = {}
  for k in K:
    # initialize agg clustering 
    AggClusterModel = AgglomerativeClustering(n_clusters=k)
    AggClusterModel.fit(df)
    cluster_labels=AggClusterModel.labels_
    #print(cluster_labels)
    # silhouette score
    sil_score = silhouette_score(df, cluster_labels)
    silhouette_avg.append(sil_score)
    if k != 2:
      sil_k[k] = sil_score
  plt.plot(K, silhouette_avg, 'bx-')
  plt.xlabel('Values of K') 
  plt.ylabel('Silhouette score') 
  plt.title('Silhouette analysis For Optimal k')
  plt.show()
  for key, value in sil_k.items(): 
   #print(key)
    if value == max(sil_k.values()): 
        opt_k = key
  #print(sil_k)
  # choose the optimum K
  return opt_k

# %%
opt_agg_k = K_sil_agg_method(CC_df_std)

# %%
print("Optimal  number of clustering using sil score is: ", opt_agg_k)
# Out:
# Optimal  number of clustering using sil score is:  6

# %% [markdown]
# > ### 3.3.2. Applyin AggloAgglomerativeClustering with optimal K = 6, method = average and metric = eculidean

# %%
CC_df_agg = CC_df.copy()
AggClusterModel = AgglomerativeClustering(n_clusters=opt_agg_k, affinity = 'euclidean', linkage = 'average')
AggClusterModel.fit(CC_df_std)
cluster_labels=AggClusterModel.labels_
CC_df_agg['clusters'] = cluster_labels

# %%
CC_df_agg
# Out:
#           BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0       40.900749           0.818182      95.40              0.00
# 1     3202.467416           0.909091       0.00              0.00
# 2     2495.148862           1.000000     773.17            773.17
# 3      817.714335           1.000000      16.00             16.00
# 4     1809.828751           1.000000    1333.28              0.00
# ...           ...                ...        ...               ...
# 8631     5.871712           0.500000      20.90             20.90
# 8632    28.493517           1.000000     291.12              0.00
# 8633    23.398673           0.833333     144.40              0.00
# 8634    13.457564           0.833333       0.00              0.00
# 8635   372.708075           0.666667    1093.25           1093.25
#
#       INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                      95.40      0.000000             0.166667
# 1                       0.00   6442.945483             0.000000
# 2                       0.00      0.000000             1.000000
# 3                       0.00      0.000000             0.083333
# 4                    1333.28      0.000000             0.666667
# ...                      ...           ...                  ...
# 8631                    0.00      0.000000             0.166667
# 8632                  291.12      0.000000             1.000000
# 8633                  144.40      0.000000             0.833333
# 8634                    0.00     36.558778             0.000000
# 8635                    0.00    127.040008             0.666667
#
#       ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# 0                       0.000000                          0.083333
# 1                       0.000000                          0.000000
# 2                       1.000000                          0.000000
# 3                       0.083333                          0.000000
# 4                       0.000000                          0.583333
# ...                          ...                               ...
# 8631                    0.166667                          0.000000
# 8632                    0.000000                          0.833333
# 8633                    0.000000                          0.666667
# 8634                    0.000000                          0.000000
# 8635                    0.666667                          0.000000
#
#       CASH_ADVANCE_FREQUENCY  CASH_ADVANCE_TRX  PURCHASES_TRX  CREDIT_LIMIT  \
# 0                   0.000000                 0              2        1000.0
# 1                   0.250000                 4              0        7000.0
# 2                   0.000000                 0             12        7500.0
# 3                   0.000000                 0              1        1200.0
# 4                   0.000000                 0              8        1800.0
# ...                      ...               ...            ...           ...
# 8631                0.000000                 0              1         500.0
# 8632                0.000000                 0              6        1000.0
# 8633                0.000000                 0              5        1000.0
# 8634                0.166667                 2              0         500.0
# 8635                0.333333                 2             23        1200.0
#
#          PAYMENTS  MINIMUM_PAYMENTS  PRC_FULL_PAYMENT  TENURE  clusters
# 0      201.802084        139.509787          0.000000      12         1
# 1     4103.032597       1072.340217          0.222222      12         1
# 2      622.066742        627.284787          0.000000      12         1
# 3      678.334763        244.791237          0.000000      12         1
# 4     1400.057770       2407.246035          0.000000      12         1
# ...           ...               ...               ...     ...       ...
# 8631    58.644883         43.473717          0.000000       6         1
# 8632   325.594462         48.886365          0.500000       6         1
# 8633    81.270775         82.418369          0.250000       6         1
# 8634    52.549959         55.755628          0.250000       6         1
# 8635    63.165404         88.288956          0.000000       6         1
#
# [8636 rows x 18 columns]

# %%
silhouette_score(CC_df_std, CC_df_agg['clusters'], metric='euclidean')
# Out:
# 0.7803420960043396

# %%
CC_df_agg = CC_df.copy()
AggClusterModel = AgglomerativeClustering(n_clusters=6, affinity = 'euclidean', linkage = 'average')
AggClusterModel.fit(CC_df_std)
cluster_labels=AggClusterModel.labels_
CC_df_agg['clusters'] = cluster_labels

# %%
CC_df_agg
# Out:
#           BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0       40.900749           0.818182      95.40              0.00
# 1     3202.467416           0.909091       0.00              0.00
# 2     2495.148862           1.000000     773.17            773.17
# 3      817.714335           1.000000      16.00             16.00
# 4     1809.828751           1.000000    1333.28              0.00
# ...           ...                ...        ...               ...
# 8631     5.871712           0.500000      20.90             20.90
# 8632    28.493517           1.000000     291.12              0.00
# 8633    23.398673           0.833333     144.40              0.00
# 8634    13.457564           0.833333       0.00              0.00
# 8635   372.708075           0.666667    1093.25           1093.25
#
#       INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                      95.40      0.000000             0.166667
# 1                       0.00   6442.945483             0.000000
# 2                       0.00      0.000000             1.000000
# 3                       0.00      0.000000             0.083333
# 4                    1333.28      0.000000             0.666667
# ...                      ...           ...                  ...
# 8631                    0.00      0.000000             0.166667
# 8632                  291.12      0.000000             1.000000
# 8633                  144.40      0.000000             0.833333
# 8634                    0.00     36.558778             0.000000
# 8635                    0.00    127.040008             0.666667
#
#       ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# 0                       0.000000                          0.083333
# 1                       0.000000                          0.000000
# 2                       1.000000                          0.000000
# 3                       0.083333                          0.000000
# 4                       0.000000                          0.583333
# ...                          ...                               ...
# 8631                    0.166667                          0.000000
# 8632                    0.000000                          0.833333
# 8633                    0.000000                          0.666667
# 8634                    0.000000                          0.000000
# 8635                    0.666667                          0.000000
#
#       CASH_ADVANCE_FREQUENCY  CASH_ADVANCE_TRX  PURCHASES_TRX  CREDIT_LIMIT  \
# 0                   0.000000                 0              2        1000.0
# 1                   0.250000                 4              0        7000.0
# 2                   0.000000                 0             12        7500.0
# 3                   0.000000                 0              1        1200.0
# 4                   0.000000                 0              8        1800.0
# ...                      ...               ...            ...           ...
# 8631                0.000000                 0              1         500.0
# 8632                0.000000                 0              6        1000.0
# 8633                0.000000                 0              5        1000.0
# 8634                0.166667                 2              0         500.0
# 8635                0.333333                 2             23        1200.0
#
#          PAYMENTS  MINIMUM_PAYMENTS  PRC_FULL_PAYMENT  TENURE  clusters
# 0      201.802084        139.509787          0.000000      12         1
# 1     4103.032597       1072.340217          0.222222      12         1
# 2      622.066742        627.284787          0.000000      12         1
# 3      678.334763        244.791237          0.000000      12         1
# 4     1400.057770       2407.246035          0.000000      12         1
# ...           ...               ...               ...     ...       ...
# 8631    58.644883         43.473717          0.000000       6         1
# 8632   325.594462         48.886365          0.500000       6         1
# 8633    81.270775         82.418369          0.250000       6         1
# 8634    52.549959         55.755628          0.250000       6         1
# 8635    63.165404         88.288956          0.000000       6         1
#
# [8636 rows x 18 columns]

# %%
silhouette_score(CC_df_std, CC_df_agg['clusters'], metric='euclidean')
# Out:
# 0.7803420960043396

# %%
CC_df_agg = CC_df.copy()
AggClusterModel = AgglomerativeClustering(n_clusters=4, affinity = 'euclidean', linkage = 'average')
AggClusterModel.fit(CC_df_std)
cluster_labels=AggClusterModel.labels_
CC_df_agg['clusters'] = cluster_labels

# %%
CC_df_agg
# Out:
#           BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0       40.900749           0.818182      95.40              0.00
# 1     3202.467416           0.909091       0.00              0.00
# 2     2495.148862           1.000000     773.17            773.17
# 3      817.714335           1.000000      16.00             16.00
# 4     1809.828751           1.000000    1333.28              0.00
# ...           ...                ...        ...               ...
# 8631     5.871712           0.500000      20.90             20.90
# 8632    28.493517           1.000000     291.12              0.00
# 8633    23.398673           0.833333     144.40              0.00
# 8634    13.457564           0.833333       0.00              0.00
# 8635   372.708075           0.666667    1093.25           1093.25
#
#       INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                      95.40      0.000000             0.166667
# 1                       0.00   6442.945483             0.000000
# 2                       0.00      0.000000             1.000000
# 3                       0.00      0.000000             0.083333
# 4                    1333.28      0.000000             0.666667
# ...                      ...           ...                  ...
# 8631                    0.00      0.000000             0.166667
# 8632                  291.12      0.000000             1.000000
# 8633                  144.40      0.000000             0.833333
# 8634                    0.00     36.558778             0.000000
# 8635                    0.00    127.040008             0.666667
#
#       ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# 0                       0.000000                          0.083333
# 1                       0.000000                          0.000000
# 2                       1.000000                          0.000000
# 3                       0.083333                          0.000000
# 4                       0.000000                          0.583333
# ...                          ...                               ...
# 8631                    0.166667                          0.000000
# 8632                    0.000000                          0.833333
# 8633                    0.000000                          0.666667
# 8634                    0.000000                          0.000000
# 8635                    0.666667                          0.000000
#
#       CASH_ADVANCE_FREQUENCY  CASH_ADVANCE_TRX  PURCHASES_TRX  CREDIT_LIMIT  \
# 0                   0.000000                 0              2        1000.0
# 1                   0.250000                 4              0        7000.0
# 2                   0.000000                 0             12        7500.0
# 3                   0.000000                 0              1        1200.0
# 4                   0.000000                 0              8        1800.0
# ...                      ...               ...            ...           ...
# 8631                0.000000                 0              1         500.0
# 8632                0.000000                 0              6        1000.0
# 8633                0.000000                 0              5        1000.0
# 8634                0.166667                 2              0         500.0
# 8635                0.333333                 2             23        1200.0
#
#          PAYMENTS  MINIMUM_PAYMENTS  PRC_FULL_PAYMENT  TENURE  clusters
# 0      201.802084        139.509787          0.000000      12         0
# 1     4103.032597       1072.340217          0.222222      12         0
# 2      622.066742        627.284787          0.000000      12         0
# 3      678.334763        244.791237          0.000000      12         0
# 4     1400.057770       2407.246035          0.000000      12         0
# ...           ...               ...               ...     ...       ...
# 8631    58.644883         43.473717          0.000000       6         0
# 8632   325.594462         48.886365          0.500000       6         0
# 8633    81.270775         82.418369          0.250000       6         0
# 8634    52.549959         55.755628          0.250000       6         0
# 8635    63.165404         88.288956          0.000000       6         0
#
# [8636 rows x 18 columns]

# %%
silhouette_score(CC_df_std, CC_df_agg['clusters'], metric='euclidean')
# Out:
# 0.8047854548225128

# %% [markdown]
# > ## 3.4. DBSCAN

# %% [markdown]
# >> ### 3.4.1. Choosing eps range using Nearest Neighbour

# %%
def NN_eps (df):
  NN_model = NearestNeighbors(n_neighbors=2).fit(df)
  distances, indices = NN_model.kneighbors(df)
  distances = np.sort(distances, axis=0)
  distances = distances[:,1]
  plt.figure(figsize=(20,10))
  plt.plot(distances)
  plt.title('K-distance Graph',fontsize=20)
  plt.xlabel('Data Points sorted by distance',fontsize=14)
  plt.ylabel('Epsilon',fontsize=14)
  plt.show()

# %%
NN_eps(CC_df_std)

# %% [markdown]
# from the graph we can conculde that most of points (almost 8000) is under eps distance of 2

# %%
eps_range = np.arange(0.1, 2, 0.2)

# %% [markdown]
# >> ### 3.4.2. Choosing eps and minPoints

# %%
def eps_minPoint(df, eps_range):
  silhouette_avg = []
  sil_eps_p = {}
  for eps in eps_range:
    for minPoints in range (3, 10): # minPoint at least  = 3
      dbscan_model = DBSCAN(eps = eps, min_samples = minPoints).fit(df)
      cluster_labels=dbscan_model.labels_
      sil_score = silhouette_score(df, cluster_labels)
      silhouette_avg.append(sil_score)
      key = str(eps) +" and "+ str(minPoints)
      sil_eps_p[key] = sil_score
      print("Eps: "+str(eps)+", minPoints: "+str(minPoints) + ", Score: " +str(sil_score)+ ", number of clusters: ", str(len(set(dbscan_model.labels_))))
  for key, value in sil_eps_p.items(): 
    if value == max(silhouette_avg): 
        print ("Optimum eps and minPoints: ", key)

# %%
eps_minPoint(CC_df_std, eps_range)
# Out:
# Eps: 0.1, minPoints: 3, Score: -0.4689633985711107, number of clusters:  42
# Eps: 0.1, minPoints: 4, Score: -0.4195692899675594, number of clusters:  23
# Eps: 0.1, minPoints: 5, Score: -0.3737304348974619, number of clusters:  12
# Eps: 0.1, minPoints: 6, Score: -0.2750774407861322, number of clusters:  6
# Eps: 0.1, minPoints: 7, Score: -0.25366918294691654, number of clusters:  4
# Eps: 0.1, minPoints: 8, Score: -0.25090328181425725, number of clusters:  3
# Eps: 0.1, minPoints: 9, Score: -0.25124562443919085, number of clusters:  3
# Eps: 0.30000000000000004, minPoints: 3, Score: -0.47800400639962526, number of clusters:  111
# Eps: 0.30000000000000004, minPoints: 4, Score: -0.42545050596702805, number of clusters:  50
# Eps: 0.30000000000000004, minPoints: 5, Score: -0.4187151511195021, number of clusters:  39
# Eps: 0.30000000000000004, minPoints: 6, Score: -0.4257845119771976, number of clusters:  32
# Eps: 0.30000000000000004, minPoints: 7, Score: -0.412799048354344, number of clusters:  22
# Eps: 0.30000000000000004, minPoints: 8, Score: -0.4041543763287258, number of clusters:  17
# Eps: 0.30000000000000004, minPoints: 9, Score: -0.3967722299164506, number of clusters:  14
# Eps: 0.5000000000000001, minPoints: 3, Score: -0.5244811903255837, number of clusters:  129
# Eps: 0.5000000000000001, minPoints: 4, Score: -0.5102458511113763, number of clusters:  63
# Eps: 0.5000000000000001, minPoints: 5, Score: -0.465117752115066, number of clusters:  37
# Eps: 0.5000000000000001, minPoints: 6, Score: -0.40228690465403466, number of clusters:  21
# Eps: 0.5000000000000001, minPoints: 7, Score: -0.385451914963475, number of clusters:  17
# Eps: 0.5000000000000001, minPoints: 8, Score: -0.3189461860956522, number of clusters:  12
# Eps: 0.5000000000000001, minPoints: 9, Score: -0.3259039450623435, number of clusters:  13
# Eps: 0.7000000000000001, minPoints: 3, Score: -0.516547422399089, number of clusters:  94
# Eps: 0.7000000000000001, minPoints: 4, Score: -0.4962803943320141, number of clusters:  49
# Eps: 0.7000000000000001, minPoints: 5, Score: -0.43770103238013724, number of clusters:  26
# Eps: 0.7000000000000001, minPoints: 6, Score: -0.39628057386883997, number of clusters:  19
# Eps: 0.7000000000000001, minPoints: 7, Score: -0.4171858369582397, number of clusters:  15
# Eps: 0.7000000000000001, minPoints: 8, Score: -0.39169298085216375, number of clusters:  14
# Eps: 0.7000000000000001, minPoints: 9, Score: -0.2970440206560081, number of clusters:  11
# Eps: 0.9000000000000001, minPoints: 3, Score: -0.4613607460814622, number of clusters:  73
# Eps: 0.9000000000000001, minPoints: 4, Score: -0.42155360008852766, number of clusters:  34
# Eps: 0.9000000000000001, minPoints: 5, Score: -0.37945823993345906, number of clusters:  18
# Eps: 0.9000000000000001, minPoints: 6, Score: -0.29368024503465107, number of clusters:  10
# Eps: 0.9000000000000001, minPoints: 7, Score: 0.002823892227602225, number of clusters:  6
# Eps: 0.9000000000000001, minPoints: 8, Score: -0.06540444057131069, number of clusters:  6
# Eps: 0.9000000000000001, minPoints: 9, Score: -0.08810964496796495, number of clusters:  10
# Eps: 1.1000000000000003, minPoints: 3, Score: -0.37535783525839655, number of clusters:  56
# Eps: 1.1000000000000003, minPoints: 4, Score: -0.2278227803762245, number of clusters:  21
# Eps: 1.1000000000000003, minPoints: 5, Score: -0.19075700839565443, number of clusters:  12
# Eps: 1.1000000000000003, minPoints: 6, Score: -0.14024688049405978, number of clusters:  7
# Eps: 1.1000000000000003, minPoints: 7, Score: -0.14447761969489614, number of clusters:  6
# Eps: 1.1000000000000003, minPoints: 8, Score: -0.1300966058827394, number of clusters:  6
# Eps: 1.1000000000000003, minPoints: 9, Score: -0.12448726756428644, number of clusters:  7
# Eps: 1.3000000000000003, minPoints: 3, Score: -0.23311242542435692, number of clusters:  32
# Eps: 1.3000000000000003, minPoints: 4, Score: -0.10035452239120227, number of clusters:  13
# Eps: 1.3000000000000003, minPoints: 5, Score: -0.022098544138090346, number of clusters:  7
# Eps: 1.3000000000000003, minPoints: 6, Score: 0.07396810580079453, number of clusters:  4
# Eps: 1.3000000000000003, minPoints: 7, Score: 0.07598173864044745, number of clusters:  4
# Eps: 1.3000000000000003, minPoints: 8, Score: 0.13868725131551515, number of clusters:  3
# Eps: 1.3000000000000003, minPoints: 9, Score: 0.2718209785631869, number of clusters:  2
# Eps: 1.5000000000000004, minPoints: 3, Score: -0.10044136048212002, number of clusters:  22
# Eps: 1.5000000000000004, minPoints: 4, Score: 0.06416386892038223, number of clusters:  10
# Eps: 1.5000000000000004, minPoints: 5, Score: -0.0023840810774559355, number of clusters:  8
# Eps: 1.5000000000000004, minPoints: 6, Score: 0.02564049975271129, number of clusters:  4
# Eps: 1.5000000000000004, minPoints: 7, Score: 0.2627808976968818, number of clusters:  3
# Eps: 1.5000000000000004, minPoints: 8, Score: 0.30215610871656123, number of clusters:  3
# Eps: 1.5000000000000004, minPoints: 9, Score: 0.3352939022170549, number of clusters:  2
# Eps: 1.7000000000000004, minPoints: 3, Score: 0.014839762145478878, number of clusters:  14
# Eps: 1.7000000000000004, minPoints: 4, Score: 0.07018768015221855, number of clusters:  6
# Eps: 1.7000000000000004, minPoints: 5, Score: 0.39328868126483263, number of clusters:  3
# Eps: 1.7000000000000004, minPoints: 6, Score: 0.4014485895989403, number of clusters:  2
# Eps: 1.7000000000000004, minPoints: 7, Score: 0.398886467869937, number of clusters:  2
# Eps: 1.7000000000000004, minPoints: 8, Score: 0.39525430310116394, number of clusters:  2
# Eps: 1.7000000000000004, minPoints: 9, Score: 0.3309185031165114, number of clusters:  3
# Eps: 1.9000000000000004, minPoints: 3, Score: 0.11487195616987556, number of clusters:  9
# Eps: 1.9000000000000004, minPoints: 4, Score: 0.18062136378642227, number of clusters:  4
# Eps: 1.9000000000000004, minPoints: 5, Score: 0.4587942262610554, number of clusters:  2
# Eps: 1.9000000000000004, minPoints: 6, Score: 0.4533564322937519, number of clusters:  2
# Eps: 1.9000000000000004, minPoints: 7, Score: 0.4468102514502899, number of clusters:  2
# Eps: 1.9000000000000004, minPoints: 8, Score: 0.4429980425010093, number of clusters:  2
# Eps: 1.9000000000000004, minPoints: 9, Score: 0.4384952983524236, number of clusters:  2
# Optimum eps and minPoints:  1.9000000000000004 and 5

# %% [markdown]
# >> ### 3.4.3. Applying DBSCAN

# %%
CC_df_dbscan = CC_df.copy()
eps = 1.9
minPoints = 5
dbscan_model = DBSCAN(eps = eps, min_samples = minPoints).fit(CC_df_std)
DBSCAN_labels=dbscan_model.labels_
CC_df_dbscan['clusters'] = DBSCAN_labels

# %%
silhouette_score(CC_df_std, DBSCAN_labels)
# Out:
# 0.4587942262610554

# %% [markdown]
# # 4. Anomaly Detection

# %% [markdown]
# > ## 4.1. Using DBSCAN

# %%
anomaly_df = CC_df[DBSCAN_labels==-1]

# %%
anomaly_df
# Out:
#            BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 5       627.260806           1.000000    7091.01           6402.63
# 20     6369.531318           1.000000    6359.95           5910.04
# 22     3800.151377           0.818182    4248.35           3454.56
# 29    12136.219960           1.000000    3038.01           1013.20
# 33     3517.101616           0.727273     547.28              0.00
# ...            ...                ...        ...               ...
# 8554   1382.936306           0.875000     336.00              0.00
# 8588    328.686581           1.000000    2806.78           2588.53
# 8605    181.891981           0.500000       0.00              0.00
# 8613    486.661842           0.833333    1898.88            939.09
# 8629   5967.475270           0.833333     214.55              0.00
#
#       INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 5                     688.38      0.000000             1.000000
# 20                    449.91    229.028245             1.000000
# 22                    793.79   7974.415626             1.000000
# 29                   2024.81   3183.583301             1.000000
# 33                    547.28      0.000000             1.000000
# ...                      ...           ...                  ...
# 8554                  336.00   4158.990631             0.875000
# 8588                  218.25      0.000000             0.857143
# 8605                    0.00   1865.191764             0.000000
# 8613                  959.79      0.000000             0.833333
# 8629                  214.55   8555.409326             0.833333
#
#       ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# 5                       1.000000                          1.000000
# 20                      0.916667                          1.000000
# 22                      0.083333                          0.916667
# 29                      0.166667                          1.000000
# 33                      0.000000                          1.000000
# ...                          ...                               ...
# 8554                    0.000000                          0.750000
# 8588                    0.714286                          0.285714
# 8605                    0.000000                          0.000000
# 8613                    0.666667                          0.666667
# 8629                    0.000000                          0.666667
#
#       CASH_ADVANCE_FREQUENCY  CASH_ADVANCE_TRX  PURCHASES_TRX  CREDIT_LIMIT  \
# 5                   0.000000                 0             64       13500.0
# 20                  0.333333                 6             92       11250.0
# 22                  0.333333                13             13        9000.0
# 29                  0.500000                10             64       13000.0
# 33                  0.000000                 0             14       11000.0
# ...                      ...               ...            ...           ...
# 8554                0.125000                 5              7        4000.0
# 8588                0.000000                 0             26        1200.0
# 8605                0.500000                10              0        2000.0
# 8613                0.000000                 0             24        1200.0
# 8629                0.666667                13              5        9000.0
#
#          PAYMENTS  MINIMUM_PAYMENTS  PRC_FULL_PAYMENT  TENURE
# 5     6354.314328        198.065894              1.00      12
# 20    2077.959051       1659.775075              0.00      12
# 22    9479.043842       1425.426525              0.00      12
# 29    4230.323491       3292.015030              0.00      12
# 33    8735.607835      17862.558310              0.00      12
# ...           ...               ...               ...     ...
# 8554   754.256439        681.059427              0.60       8
# 8588  1796.886852         93.017466              0.25       7
# 8605  4565.356495         88.057892              1.00       6
# 8613   669.039640        336.880119              0.50       6
# 8629   966.202912        861.949906              0.00       6
#
# [695 rows x 17 columns]

# %% [markdown]
# > ## 4.2. Using EM

# %%
GmmModel = GaussianMixture(n_components = 2, covariance_type = 'spherical', max_iter = 300, verbose = 1, tol = 0.00001)
GmmModel.fit(CC_df_std)
# Out:
# Initialization 0
#   Iteration 10
#   Iteration 20
#   Iteration 30
# Initialization converged: True
# GaussianMixture(covariance_type='spherical', max_iter=300, n_components=2,
#                 tol=1e-05, verbose=1)

# %%
CC_df_Gmm = CC_df.copy()
Gmmlabels = GmmModel.predict(CC_df_std)
Gmmscore = GmmModel.score_samples(CC_df_std)
CC_df_Gmm['labels'] = Gmmlabels
#CC_df_Gmm['scores'] = Gmmscore
CC_df_Gmm
# Out:
#           BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0       40.900749           0.818182      95.40              0.00
# 1     3202.467416           0.909091       0.00              0.00
# 2     2495.148862           1.000000     773.17            773.17
# 3      817.714335           1.000000      16.00             16.00
# 4     1809.828751           1.000000    1333.28              0.00
# ...           ...                ...        ...               ...
# 8631     5.871712           0.500000      20.90             20.90
# 8632    28.493517           1.000000     291.12              0.00
# 8633    23.398673           0.833333     144.40              0.00
# 8634    13.457564           0.833333       0.00              0.00
# 8635   372.708075           0.666667    1093.25           1093.25
#
#       INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                      95.40      0.000000             0.166667
# 1                       0.00   6442.945483             0.000000
# 2                       0.00      0.000000             1.000000
# 3                       0.00      0.000000             0.083333
# 4                    1333.28      0.000000             0.666667
# ...                      ...           ...                  ...
# 8631                    0.00      0.000000             0.166667
# 8632                  291.12      0.000000             1.000000
# 8633                  144.40      0.000000             0.833333
# 8634                    0.00     36.558778             0.000000
# 8635                    0.00    127.040008             0.666667
#
#       ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# 0                       0.000000                          0.083333
# 1                       0.000000                          0.000000
# 2                       1.000000                          0.000000
# 3                       0.083333                          0.000000
# 4                       0.000000                          0.583333
# ...                          ...                               ...
# 8631                    0.166667                          0.000000
# 8632                    0.000000                          0.833333
# 8633                    0.000000                          0.666667
# 8634                    0.000000                          0.000000
# 8635                    0.666667                          0.000000
#
#       CASH_ADVANCE_FREQUENCY  CASH_ADVANCE_TRX  PURCHASES_TRX  CREDIT_LIMIT  \
# 0                   0.000000                 0              2        1000.0
# 1                   0.250000                 4              0        7000.0
# 2                   0.000000                 0             12        7500.0
# 3                   0.000000                 0              1        1200.0
# 4                   0.000000                 0              8        1800.0
# ...                      ...               ...            ...           ...
# 8631                0.000000                 0              1         500.0
# 8632                0.000000                 0              6        1000.0
# 8633                0.000000                 0              5        1000.0
# 8634                0.166667                 2              0         500.0
# 8635                0.333333                 2             23        1200.0
#
#          PAYMENTS  MINIMUM_PAYMENTS  PRC_FULL_PAYMENT  TENURE  labels
# 0      201.802084        139.509787          0.000000      12       1
# 1     4103.032597       1072.340217          0.222222      12       1
# 2      622.066742        627.284787          0.000000      12       1
# 3      678.334763        244.791237          0.000000      12       1
# 4     1400.057770       2407.246035          0.000000      12       1
# ...           ...               ...               ...     ...     ...
# 8631    58.644883         43.473717          0.000000       6       0
# 8632   325.594462         48.886365          0.500000       6       0
# 8633    81.270775         82.418369          0.250000       6       0
# 8634    52.549959         55.755628          0.250000       6       0
# 8635    63.165404         88.288956          0.000000       6       0
#
# [8636 rows x 18 columns]

# %%
Gmmscore.shape
# Out:
# (8636,)

# %%
thresh = np.quantile(Gmmscore, 0.03)
print(thresh)
# Out:
# -35.426247704394115

# %%
outlier_df = CC_df_Gmm[Gmmscore<thresh]
outlier_df
# Out:
#            BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 33     3517.101616           0.727273     547.28              0.00
# 47     4931.331857           1.000000     901.42            646.07
# 64     2990.422186           0.909091    4523.27           1664.09
# 110   14224.115410           1.000000       0.00              0.00
# 111    2392.917738           1.000000   12462.44          12462.44
# ...            ...                ...        ...               ...
# 7963   2144.040539           1.000000       0.00              0.00
# 8039   2648.244646           1.000000       0.00              0.00
# 8141   3911.628474           0.875000       0.00              0.00
# 8250   3326.323283           1.000000    8209.77           2218.28
# 8548   2330.222764           1.000000    1320.00              0.00
#
#       INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 33                    547.28      0.000000             1.000000
# 47                    255.35   8530.648614             0.625000
# 64                   2859.18  27296.485760             0.666667
# 110                     0.00   4614.427403             0.000000
# 111                     0.00      0.000000             0.916667
# ...                      ...           ...                  ...
# 7963                    0.00  14127.466640             0.000000
# 8039                    0.00  10458.978150             0.000000
# 8141                    0.00  11951.903320             0.000000
# 8250                 5991.49      0.000000             1.000000
# 8548                 1320.00  14926.790590             0.428571
#
#       ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# 33                      0.000000                          1.000000
# 47                      0.375000                          0.250000
# 64                      0.500000                          0.583333
# 110                     0.000000                          0.000000
# 111                     0.916667                          0.000000
# ...                          ...                               ...
# 7963                    0.000000                          0.000000
# 8039                    0.000000                          0.000000
# 8141                    0.000000                          0.000000
# 8250                    0.416667                          1.000000
# 8548                    0.000000                          0.285714
#
#       CASH_ADVANCE_FREQUENCY  CASH_ADVANCE_TRX  PURCHASES_TRX  CREDIT_LIMIT  \
# 33                  0.000000                 0             14       11000.0
# 47                  0.875000                37              9       12000.0
# 64                  0.833333                27             33        7000.0
# 110                 0.333333                 9              0       19000.0
# 111                 0.000000                 0            217        2800.0
# ...                      ...               ...            ...           ...
# 7963                0.416667                23              0        3500.0
# 8039                1.000000               123              0        4000.0
# 8141                0.500000                40              0        7000.0
# 8250                0.000000                 0            130       10000.0
# 8548                0.571429                10              3       10000.0
#
#           PAYMENTS  MINIMUM_PAYMENTS  PRC_FULL_PAYMENT  TENURE  labels
# 33     8735.607835      17862.558310          0.000000      12       0
# 47     8113.297346       1012.415961          0.000000       8       0
# 64    28232.694460       1107.030803          0.454545      12       0
# 110    3066.614272       3406.258999          0.000000      12       0
# 111   11628.715570       2000.990921          0.000000      12       0
# ...            ...               ...               ...     ...     ...
# 7963  12571.814660        525.168936          0.300000      12       0
# 8039   9818.531412        665.888853          0.000000      12       0
# 8141   7918.877416        905.569605          0.166667       8       0
# 8250   1942.074765        702.905059          0.083333      12       0
# 8548   8157.666434        283.362434          0.200000       7       0
#
# [260 rows x 18 columns]

# %% [markdown]
# > ## 4.3. Using IsolatedForest

# %%
IsoForModel = IsolationForest(n_estimators = 100, max_samples = 'auto', contamination = 0.1, max_features = 1)
IsoForModel.fit(CC_df_std)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but IsolationForest was fitted with feature names
#   "X does not have valid feature names, but"
# IsolationForest(contamination=0.1, max_features=1)

# %%
IsoAnomlabels = IsoForModel.predict(CC_df_std)

# %%
anomaly_df = CC_df[IsoAnomlabels==-1]
anomaly_df
# Out:
#            BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 5       627.260806           1.000000    7091.01           6402.63
# 20     6369.531318           1.000000    6359.95           5910.04
# 22     3800.151377           0.818182    4248.35           3454.56
# 29    12136.219960           1.000000    3038.01           1013.20
# 33     3517.101616           0.727273     547.28              0.00
# ...            ...                ...        ...               ...
# 8603    376.547421           0.857143     520.00            280.00
# 8605    181.891981           0.500000       0.00              0.00
# 8609     11.294184           0.666667     155.00              0.00
# 8629   5967.475270           0.833333     214.55              0.00
# 8634     13.457564           0.833333       0.00              0.00
#
#       INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 5                     688.38      0.000000             1.000000
# 20                    449.91    229.028245             1.000000
# 22                    793.79   7974.415626             1.000000
# 29                   2024.81   3183.583301             1.000000
# 33                    547.28      0.000000             1.000000
# ...                      ...           ...                  ...
# 8603                  240.00   1178.402416             0.857143
# 8605                    0.00   1865.191764             0.000000
# 8609                  155.00      0.000000             0.666667
# 8629                  214.55   8555.409326             0.833333
# 8634                    0.00     36.558778             0.000000
#
#       ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# 5                       1.000000                          1.000000
# 20                      0.916667                          1.000000
# 22                      0.083333                          0.916667
# 29                      0.166667                          1.000000
# 33                      0.000000                          1.000000
# ...                          ...                               ...
# 8603                    0.142857                          0.714286
# 8605                    0.000000                          0.000000
# 8609                    0.000000                          0.500000
# 8629                    0.000000                          0.666667
# 8634                    0.000000                          0.000000
#
#       CASH_ADVANCE_FREQUENCY  CASH_ADVANCE_TRX  PURCHASES_TRX  CREDIT_LIMIT  \
# 5                   0.000000                 0             64       13500.0
# 20                  0.333333                 6             92       11250.0
# 22                  0.333333                13             13        9000.0
# 29                  0.500000                10             64       13000.0
# 33                  0.000000                 0             14       11000.0
# ...                      ...               ...            ...           ...
# 8603                0.714286                 9              7        1000.0
# 8605                0.500000                10              0        2000.0
# 8609                0.000000                 0              4        1000.0
# 8629                0.666667                13              5        9000.0
# 8634                0.166667                 2              0         500.0
#
#          PAYMENTS  MINIMUM_PAYMENTS  PRC_FULL_PAYMENT  TENURE
# 5     6354.314328        198.065894              1.00      12
# 20    2077.959051       1659.775075              0.00      12
# 22    9479.043842       1425.426525              0.00      12
# 29    4230.323491       3292.015030              0.00      12
# 33    8735.607835      17862.558310              0.00      12
# ...           ...               ...               ...     ...
# 8603   929.415656        103.927887              0.20       7
# 8605  4565.356495         88.057892              1.00       6
# 8609   149.588599         43.341698              0.50       6
# 8629   966.202912        861.949906              0.00       6
# 8634    52.549959         55.755628              0.25       6
#
# [864 rows x 17 columns]

# %% [markdown]
# # Final Model

# %% [markdown]
# using AgglomerativeClustering sith heighest silhoutte score and clusters = 6

# %%
cc_df_test_std = cc_df_test.copy()
columns = cc_df_test_std.columns
features = cc_df_test_std[columns]
cc_df_test_std[columns] = StandardScaler().fit_transform(features.values)

# %%
cc_df_test_label = cc_df_test.copy()
AggClusterModel = AgglomerativeClustering(n_clusters=6, affinity = 'euclidean', linkage = 'average')
labels = AggClusterModel.fit_predict(cc_df_test_std)
cc_df_test_label ['cluster'] = labels

# %%
cc_df_test_label
# Out:
#           BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 2263    19.112841           1.000000     504.20              0.00
# 6255   834.825957           1.000000       0.00              0.00
# 7316    29.466141           0.545455     149.00            149.00
# 2045   226.030380           1.000000     435.08            435.08
# 5253    38.160715           0.545455     340.00              0.00
# ...           ...                ...        ...               ...
# 705   1350.286625           1.000000     642.33            642.33
# 6500    82.902896           0.727273     430.43              0.00
# 7873   226.306461           0.363636       0.00              0.00
# 6652     9.153671           0.272727     126.60              0.00
# 5198   658.655200           1.000000     629.99            629.99
#
#       INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 2263                  504.20      0.000000             1.000000
# 6255                    0.00   1195.000251             0.000000
# 7316                    0.00      0.000000             0.083333
# 2045                    0.00      0.000000             0.916667
# 5253                  340.00      0.000000             0.500000
# ...                      ...           ...                  ...
# 705                     0.00      0.000000             0.500000
# 6500                  430.43      0.000000             0.500000
# 7873                    0.00    788.235661             0.000000
# 6652                  126.60      0.000000             0.500000
# 5198                    0.00      0.000000             0.083333
#
#       ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# 2263                    0.000000                          1.000000
# 6255                    0.000000                          0.000000
# 7316                    0.083333                          0.000000
# 2045                    0.916667                          0.000000
# 5253                    0.000000                          0.416667
# ...                          ...                               ...
# 705                     0.500000                          0.000000
# 6500                    0.000000                          0.416667
# 7873                    0.000000                          0.000000
# 6652                    0.000000                          0.416667
# 5198                    0.083333                          0.000000
#
#       CASH_ADVANCE_FREQUENCY  CASH_ADVANCE_TRX  PURCHASES_TRX  CREDIT_LIMIT  \
# 2263                0.000000                 0             20        1000.0
# 6255                0.250000                 6              0        1200.0
# 7316                0.000000                 0              1        1000.0
# 2045                0.000000                 0             15        7500.0
# 5253                0.000000                 0              6        5000.0
# ...                      ...               ...            ...           ...
# 705                 0.000000                 0             12        9000.0
# 6500                0.000000                 0             10        2500.0
# 7873                0.166667                 3              0        1200.0
# 6652                0.000000                 0              6        2900.0
# 5198                0.000000                 0              1        6000.0
#
#          PAYMENTS  MINIMUM_PAYMENTS  PRC_FULL_PAYMENT  TENURE  cluster
# 2263   476.370018        130.862225          0.727273      12        1
# 6255  1392.439311        221.752549          0.100000      12        1
# 7316   350.176472        215.215582          0.000000      12        1
# 2045  3796.014359        180.308803          0.200000      12        1
# 5253   888.221177        146.348596          1.000000      12        1
# ...           ...               ...               ...     ...      ...
# 705    323.683167        344.973051          0.000000      12        1
# 6500   315.075002         87.824996          0.083333      12        1
# 7873   184.701045        217.492643          0.000000      12        1
# 6652   134.386353         46.037748          0.000000      12        1
# 5198   353.862252        247.500183          0.000000      12        1
#
# [1728 rows x 18 columns]

# %% [markdown]
# #### Detecting if there are any anomalies

# %%
IsoForModel = IsolationForest(n_estimators = 100, max_samples = 'auto', contamination = 0.1, max_features = 1)
IsoForModel.fit(cc_df_test_std)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but IsolationForest was fitted with feature names
#   "X does not have valid feature names, but"
# IsolationForest(contamination=0.1, max_features=1)

# %%
IsoAnomlabels = IsoForModel.predict(cc_df_test_std)

# %%
anomaly_df = cc_df_test[IsoAnomlabels==-1]
anomaly_df
# Out:
#           BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 2517  6810.401782           1.000000     635.76            164.32
# 1458  3608.548972           0.900000    1664.02           1620.60
# 1063  4550.717687           1.000000    2094.99           1357.00
# 7998  1410.909779           1.000000     698.88              0.00
# 5440  8894.553534           1.000000     476.84            476.84
# ...           ...                ...        ...               ...
# 4058   889.090252           1.000000    9751.90           5896.76
# 4363  7558.010921           1.000000     365.26            188.56
# 3909   293.614532           0.857143     839.61            839.61
# 3732  5000.825577           1.000000    3310.39           3072.89
# 2098  4068.162699           1.000000    3387.47           1938.13
#
#       INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 2517                  471.44   3863.405310             0.916667
# 1458                   43.42   3899.963528             0.500000
# 1063                  737.99   2392.186586             1.000000
# 7998                  698.88    948.848018             1.000000
# 5440                    0.00   6098.490836             0.166667
# ...                      ...           ...                  ...
# 4058                 3855.14      0.000000             1.000000
# 4363                  176.70   4738.307540             0.500000
# 3909                    0.00   2018.794348             0.714286
# 3732                  237.50   2019.865472             0.750000
# 2098                 1449.34      0.000000             1.000000
#
#       ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# 2517                    0.083333                          0.916667
# 1458                    0.500000                          0.100000
# 1063                    0.500000                          1.000000
# 7998                    0.000000                          1.000000
# 5440                    0.166667                          0.000000
# ...                          ...                               ...
# 4058                    1.000000                          0.916667
# 4363                    0.083333                          0.416667
# 3909                    0.714286                          0.000000
# 3732                    0.666667                          0.333333
# 2098                    1.000000                          1.000000
#
#       CASH_ADVANCE_FREQUENCY  CASH_ADVANCE_TRX  PURCHASES_TRX  CREDIT_LIMIT  \
# 2517                0.250000                13             17       10000.0
# 1458                0.300000                 5             15        5000.0
# 1063                0.166667                 2             23        7600.0
# 7998                0.166667                 8             12        1200.0
# 5440                0.583333                16              3       12000.0
# ...                      ...               ...            ...           ...
# 4058                0.000000                 0            115        4500.0
# 4363                0.666667                25              9        8000.0
# 3909                0.857143                12             11        3000.0
# 3732                0.083333                 1             28        7500.0
# 2098                0.000000                 0             86        8500.0
#
#          PAYMENTS  MINIMUM_PAYMENTS  PRC_FULL_PAYMENT  TENURE
# 2517  3161.148768       3781.907645          0.000000      12
# 1458  1043.772722       1488.313908          0.000000      10
# 1063  3172.264416       1091.281356          0.000000      12
# 7998    79.578186      11795.280960          0.083333      12
# 5440  2163.376448       2871.461432          0.000000      12
# ...           ...               ...               ...     ...
# 4058  8418.403666        206.690230          0.666667      12
# 4363  3311.192387       4903.859993          0.000000      12
# 3909  2585.110269        102.177146          0.500000       7
# 3732  2633.433636       2412.441231          0.000000      12
# 2098  1312.481879       1245.153414          0.000000      12
#
# [173 rows x 17 columns]

# %% [markdown]
# #### Graph of 6 segments using PCA

# %%
CC_df_std_nor = normalize(cc_df_test_std)
Kpca = KernelPCA(n_components = 2, kernel = 'rbf').fit(CC_df_std_nor)
df_Kpca  = Kpca.fit_transform(CC_df_std_nor)

# %%
Kpca_df = pd.DataFrame(df_Kpca, columns = ["PCA1", "PCA2"])
Kpca_df
# Out:
#           PCA1      PCA2
# 0     0.203738 -0.140351
# 1    -0.261360 -0.028172
# 2    -0.153387 -0.188982
# 3     0.113717  0.052342
# 4     0.058932 -0.140944
# ...        ...       ...
# 1723 -0.009792  0.035608
# 1724 -0.008211 -0.264078
# 1725 -0.172870 -0.122585
# 1726 -0.021398 -0.175693
# 1727 -0.175406 -0.092243
#
# [1728 rows x 2 columns]

# %%
Kpca_df.shape
#columns.shape
# Out:
# (1728, 2)

# %%
labels = AggClusterModel.fit_predict(Kpca_df)
plt.scatter(Kpca_df['PCA1'], Kpca_df['PCA2'],
            c = labels) 
plt.show()

# %% [markdown]
# >### There are 6 Segements

# %% [markdown]
# >> #### Seg 1

# %% [markdown]
# -  Increased balances.
# - Average purchases, mainly one-off.
# - Low cash advance usage.
# - Increased balances compared to their purchases suggest that they tend to carry past balances; this conclusion is also indicated by increased usage of  their limit (balance to credit limit ratio).
# - They seem to pay a small amount of their due balance every month, as indicated by the low payments to statement balance ratio. Their ‘‘revolver’’ behavior is also suggested by the fact that they have the lowest percentage of months with full payment of their due balance.

# %% [markdown]
# >> #### Seg 2

# %% [markdown]
# - Highest cash advance usage in terms of frequency and amount of cash withdrawals.
# - Few purchases.
# - 85% of their total card spending is attributed to cash advances.
# - Highest monthly balance amounts.
# - They also present high limit usage.
# - they tend to carry past balances and pay only a part of their monthly  balances as indicated by the low frequency of full payments and the similarly low ratio of payments to balance.

# %% [markdown]
# >> #### Seg 3

# %% [markdown]
# - Highest purchases, in terms of frequency and volume.
# - One-off as well as installment purchases.
# - Moderate balances and limit usage.
# - Their spending is almost exclusively purchases since their cash advance usage is low.
# - Their high payments to balance ratio and frequency of full payments suggest a transactor behavior.

# %% [markdown]
# >> #### Seg 4

# %% [markdown]
# - Relatively low purchases.
# - Their spending is almost exclusively on installments.
# - Moderate balances.

# %% [markdown]
# >> #### Seg 5

# %% [markdown]
# - Lowest purchases and cash advance usage.
# - Lowest ratio of balance to credit limit.
# - Insignificant (remnant?) balances.

# %% [markdown]
# >> #### Seg6

# %% [markdown]
# - Increased purchases, including almost exclusively one-off purchases.
# - High-value but infrequent purchase transactions: their purchase frequency is
# relatively low; however, they have the largest average amount per purchase transaction.
# - Moderate balances and credit limit usage.
# - They present a transactor behavior.

# %% [markdown]
# ------

# %% [markdown]
# # Scenario 2

# %% [markdown]
# # 2. Data Preparation for Model

# %% [markdown]
# > ## 2.1. Adding new Column related to Scenario

# %%
Amount_owned_col = 0.3 * (CC_data ['BALANCE'] / CC_data['CREDIT_LIMIT'])
Payment_history_col = 0.35 * (CC_data ['PRC_FULL_PAYMENT'])

# %%
CC_loan_df = pd.DataFrame (Amount_owned_col, columns = ['AMOUNT_OWN'])
CC_loan_df['PAYMENT_HISTORY'] = Payment_history_col
CC_loan_df
# Out:
#       AMOUNT_OWN  PAYMENT_HISTORY
# 0       0.012270         0.000000
# 1       0.137249         0.077778
# 2       0.099806         0.000000
# 3       0.204429         0.000000
# 4       0.301638         0.000000
# ...          ...              ...
# 8631    0.003523         0.000000
# 8632    0.008548         0.175000
# 8633    0.007020         0.087500
# 8634    0.008075         0.087500
# 8635    0.093177         0.000000
#
# [8636 rows x 2 columns]

# %% [markdown]
# > ## 2.1. Data Splitting

# %%
CC_df, cc_df_test = train_test_split(CC_loan_df, test_size=0.2, random_state=1)

# %% [markdown]
# > ## 2.2.  Scaling and Transform

# %% [markdown]
# >>>### 2.2.1. LogTransform

# %%
CC_df_log = CC_df.copy()
columns = CC_df_log.columns
for col in columns:
  CC_df_log [col] = np.log(CC_df_log[col]+1)

# %%
CC_df_log.describe().T
# Out:
#                   count      mean       std  min       25%       50%  \
# AMOUNT_OWN       6908.0  0.107750  0.095199  0.0  0.014194  0.090917
# PAYMENT_HISTORY  6908.0  0.050398  0.090502  0.0  0.000000  0.000000
#
#                       75%       max
# AMOUNT_OWN       0.196387  1.753189
# PAYMENT_HISTORY  0.056695  0.300105

# %% [markdown]
# >>> #### 1.2.2.2. StandardScaler -> scaling to unit variance

# %%
CC_df_std = CC_df.copy()
columns = CC_df_std.columns
features = CC_df_std[columns]
CC_df_std[columns] = StandardScaler().fit_transform(features.values)

# %%
CC_df_std.describe().T
# Out:
#                   count          mean       std       min       25%       50%  \
# AMOUNT_OWN       6908.0  8.434352e-17  1.000072 -0.994128 -0.874775 -0.199468
# PAYMENT_HISTORY  6908.0  1.594298e-17  1.000072 -0.542843 -0.542843 -0.542843
#
#                       75%        max
# AMOUNT_OWN       0.817617  38.856193
# PAYMENT_HISTORY  0.020175   2.835255

# %%
# Histogram 
CC_df_std[columns].hist(bins=15, figsize=(20, 15), layout=(5, 4))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fed018d9510>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fed0477f550>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fed0477a9d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fed0b7faf90>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fed0b807710>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fed0a6a9c10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fed01bff150>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fed0a336650>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fed0a350790>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fed09094d50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fed08abc590>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fed03ae8e90>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fed03addb50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fed048c64d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fed083189d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fed08e0eed0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fed0bcc9410>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fed071aa910>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fed05563e10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fed05947350>]],
#       dtype=object)

# %% [markdown]
# >>> #### 1.2.2.3. RobustScaler -> standardization to a unit value of a robust variance estimator

# %%
CC_df_robust = CC_df.copy()
columns = CC_df_robust.columns
features = CC_df_robust[columns]
CC_df_robust[columns] = RobustScaler().fit_transform(features.values)

# %%
CC_df_robust.describe().T
# Out:
#                   count      mean       std       min       25%  50%  \
# AMOUNT_OWN       6908.0  0.117862  0.590922 -0.469548 -0.399025  0.0
# PAYMENT_HISTORY  6908.0  0.964167  1.776273  0.000000  0.000000  0.0
#
#                       75%        max
# AMOUNT_OWN       0.600975  23.077198
# PAYMENT_HISTORY  1.000000   5.999988

# %%
# Histogram 
CC_df_robust[columns].hist(bins=15, figsize=(20, 15), layout=(5, 4))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fed09a783d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fed06b99590>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fed0bfaba10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fed084e9690>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fed07a85cd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fed077d00d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fed06f375d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fed06e26ad0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fed06e5ec10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fed056ed210>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fed055cda10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fed082d4f10>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fed0a854450>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fed0af67250>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fed08f57290>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fed0a30f390>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fed08fe4410>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fed11380d50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fed06482290>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fed0a059790>]],
#       dtype=object)

# %% [markdown]
# >>> #### 1.2.2.4. MinMaxScaler ->  standardization to [0, 1]-range

# %%
CC_df_minmax = CC_df.copy()
columns = CC_df_minmax.columns
features = CC_df_minmax[columns]
CC_df_minmax[columns] = MinMaxScaler().fit_transform(features.values)

# %%
CC_df_minmax.describe().T
# Out:
#                   count      mean       std  min       25%       50%  \
# AMOUNT_OWN       6908.0  0.024947  0.025096  0.0  0.002995  0.019941
# PAYMENT_HISTORY  6908.0  0.160695  0.296046  0.0  0.000000  0.000000
#
#                       75%  max
# AMOUNT_OWN       0.045464  1.0
# PAYMENT_HISTORY  0.166667  1.0

# %%
# Histogram 
CC_df_minmax[columns].hist(bins=15, figsize=(20, 15), layout=(5, 4))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fed06dd9390>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fed06ff3590>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fed087e0b90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fed079d21d0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fed080956d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fed052f4bd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fed03618110>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fed09f59610>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fed09f3c750>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fed06793d10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fed03783550>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fed02525a50>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fed0815a850>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fed0510d490>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fed0798f990>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fed07970e90>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fed0465a9d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fed046648d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fed08226f50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fed078dd310>]],
#       dtype=object)

# %% [markdown]
# # 3. Different Clustering Techniques

# %% [markdown]
# > ## 3.1. KMeans Clustering

# %% [markdown]
# >> ### 3.1.1. Get Optimal number of clustering K

# %% [markdown]
# >>> #### 3.1.1.1. Using Silhoutte method to get optimumal

# %%
def K_sil_method(df):
  K = range(2,10)
  silhouette_avg = []
  opt_k = 0
  sil_k = {}
  for k in K:
    # initialise kmeans
    kmeanModel = KMeans(n_clusters=k)
    kmeanModel.fit(df)
    cluster_labels=kmeanModel.labels_
    #print(cluster_labels)
    # silhouette score
    sil_score = silhouette_score(df, cluster_labels)
    silhouette_avg.append(sil_score)
    sil_k[k] = sil_score
  plt.plot(K, silhouette_avg, 'bx-')
  plt.xlabel('Values of K') 
  plt.ylabel('Silhouette score') 
  plt.title('Silhouette analysis For Optimal k')
  plt.show()
  for key, value in sil_k.items(): 
         if max(silhouette_avg) == value: 
             opt_k = key
        
  # choose the optimum K
  return opt_k

# %%
opt_k_sil = K_sil_method(CC_df_std)

# %%
print("The optimal K using silhoutte score: ", opt_k_sil)
# Out:
# The optimal K using silhoutte score:  4

# %% [markdown]
# >>> #### 3.1.1.2. Using Elbow method to get optimumal K

# %%
def elbow_method(df):
  distortions = []
  K = range(1,10)
  opt_k = 0
  for k in K:
      kmeanModel = KMeans(n_clusters=k)
      kmeanModel.fit(df)
      distortions.append((kmeanModel.inertia_)/k)
      cluster_labels = kmeanModel.labels_
  #print(len(distortions)-1)
  for i in range (1, len(distortions)-1):
   # print(i)
    if (distortions[i]-distortions[i+1])/(distortions[i-1]-distortions[i]) > 0.5:
      opt_k = i
   #   print(opt_k)
      break
  #print(distortions)
  plt.figure(figsize=(16,8))
  plt.plot(K, distortions, 'bx-')
  plt.xlabel('k')
  plt.ylabel('Distortion')
  plt.title('The Elbow Method showing the optimal k')
  plt.show()
  return opt_k

# %%
opt_k_elbow = elbow_method(CC_df_std)

# %%
print("The optimal K using elbow method: ", opt_k_elbow)
# Out:
# The optimal K using elbow method:  4

# %% [markdown]
# >> ### 3.1.2. Applying Kmean Clustering using optimal K

# %%
def Kmeans_plot (df, k):
  plt.rcParams['figure.figsize'] =(25,40)
  for num in range(0,17):
      ax = plt.subplot(5,4,num+1)
      col = df.columns[num]
      sns.stripplot(df['constant'],df[col], ax=ax, hue=df['label'])
      plt.xlabel('constant')

  plt.show()

# %%
CC_df_k = CC_df.copy()
kmeanModel = KMeans(n_clusters=opt_k_elbow)
kmeanModel.fit_predict(CC_df_std)
labels = kmeanModel.labels_
CC_df_k['clusters'] = labels

# %%
CC_df_k
# Out:
#       AMOUNT_OWN  PAYMENT_HISTORY  clusters
# 975     0.009844         0.058333         2
# 4807    0.199456         0.000000         0
# 147     0.030866         0.000000         2
# 4708    0.060448         0.029167         2
# 543     0.283534         0.000000         0
# ...          ...              ...       ...
# 2895    0.262168         0.000000         0
# 7813    0.281908         0.000000         0
# 905     0.238849         0.000000         0
# 5192    0.131273         0.000000         2
# 235     0.204148         0.029167         0
#
# [6908 rows x 3 columns]

# %%
# CC_df_minmax_label = CC_df_minmax.copy()
# Kmeans_plot(CC_df_minmax_label, opt_k_sil)

# %%
for c in CC_df_k:
    grid= sns.FacetGrid(CC_df_k, col='clusters')
    grid.map(plt.hist, c)

# %%
silhouette_score(CC_df_std, CC_df_k['clusters'], metric='euclidean')
# Out:
# 0.5946948825273408

# %% [markdown]
# >> ### 3.1.3. KMeans Clustering using PCA

# %%
CC_df_std_nor = normalize(CC_df_std)
pca = PCA(n_components = 2).fit(CC_df_std_nor)
df_pca  = pca.fit_transform(CC_df_std_nor)

# %%
pca_df = pd.DataFrame(df_pca, columns = ["PCA1", "PCA2"])
pca_df
# Out:
#           PCA1      PCA2
# 0     0.993712 -0.216880
# 1    -0.880329  0.048518
# 2     0.531359 -0.667419
# 3     0.657167 -0.596023
# 4    -0.891365  0.350771
# ...        ...       ...
# 6903 -0.895874  0.300982
# 6904 -0.891751  0.347384
# 6905 -0.897991  0.230193
# 6906 -0.524716 -0.543541
# 6907 -0.888326  0.374514
#
# [6908 rows x 2 columns]

# %%
pca_df.shape
#columns.shape
# Out:
# (6908, 2)

# %%
kmeanModel = KMeans(n_clusters=opt_k_elbow)
labels = kmeanModel.fit_predict(pca_df)
plt.scatter(pca_df['PCA1'], pca_df['PCA2'],
            c = labels) 
plt.show()

# %%
silhouette_score(pca_df, labels, metric='euclidean')
# Out:
# 0.6709091820879243

# %% [markdown]
# >> ### 3.1.4. KMeans Clustering using KernelPCA

# %%
CC_df_std_nor = normalize(CC_df_std)
Kpca = KernelPCA(n_components = 2, kernel = 'rbf').fit(CC_df_std_nor)
df_Kpca  = Kpca.fit_transform(CC_df_std_nor)

# %%
Kpca_df = pd.DataFrame(df_Kpca, columns = ["PCA1", "PCA2"])
Kpca_df
# Out:
#           PCA1      PCA2
# 0     0.620079 -0.045121
# 1    -0.610780  0.018009
# 2     0.447614 -0.477769
# 3     0.504702 -0.409599
# 4    -0.628716  0.153862
# ...        ...       ...
# 6903 -0.632018  0.133504
# 6904 -0.629018  0.152500
# 6905 -0.632503  0.103264
# 6906 -0.266518 -0.355216
# 6907 -0.626283  0.163320
#
# [6908 rows x 2 columns]

# %%
Kpca_df.shape
#columns.shape
# Out:
# (6908, 2)

# %%
kmeanModel = KMeans(n_clusters=opt_k_elbow)
labels = kmeanModel.fit_predict(Kpca_df)
plt.scatter(Kpca_df['PCA1'], Kpca_df['PCA2'],
            c = labels) 
plt.show()

# %%
silhouette_score(Kpca_df, labels, metric='euclidean')
# Out:
# 0.7069414471937712

# %% [markdown]
# >> ### 3.1.5. KMeans Clustering using TSNE

# %%
CC_df_std_nor = normalize(CC_df_std)
tsne = TSNE(n_components=2, verbose=1, perplexity=40, n_iter=300)
df_tsne = tsne.fit_transform(CC_df_std_nor)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/manifold/_t_sne.py:783: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/manifold/_t_sne.py:793: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   FutureWarning,
# [t-SNE] Computing 121 nearest neighbors...
# [t-SNE] Indexed 6908 samples in 0.008s...
# [t-SNE] Computed neighbors for 6908 samples in 0.100s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 6908
# [t-SNE] Computed conditional probabilities for sample 2000 / 6908
# [t-SNE] Computed conditional probabilities for sample 3000 / 6908
# [t-SNE] Computed conditional probabilities for sample 4000 / 6908
# [t-SNE] Computed conditional probabilities for sample 5000 / 6908
# [t-SNE] Computed conditional probabilities for sample 6000 / 6908
# [t-SNE] Computed conditional probabilities for sample 6908 / 6908
# [t-SNE] Mean sigma: 0.002000
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 56.771187
# [t-SNE] KL divergence after 300 iterations: 1.387563

# %%
tsne_df = pd.DataFrame(df_tsne, columns = ["TSNE1", "TSNE2"])
tsne_df
# Out:
#           TSNE1      TSNE2
# 0    -14.945552  -5.656172
# 1     -1.675665   2.936349
# 2      6.311508 -10.238110
# 3     -6.144040   0.122466
# 4     -4.205143  11.762777
# ...         ...        ...
# 6903   6.726366 -14.049254
# 6904  -3.949289   8.742608
# 6905  14.663508  -2.146187
# 6906   5.294258   7.486319
# 6907  -2.278898  10.503000
#
# [6908 rows x 2 columns]

# %%
kmeansModel = KMeans(n_clusters=opt_k_elbow)
labels = kmeansModel.fit_predict(tsne_df)
plt.scatter(tsne_df['TSNE1'], tsne_df['TSNE2'],
            c = labels) 
plt.show()

# %% [markdown]
# > ## 3.2. KMediods Clustering

# %% [markdown]
# >> ### 3.2.1. Get Optimal number of clustering K

# %% [markdown]
# >>> #### 3.2.1.1. Using Silhoutte method to get optimal K

# %%
def K_sil_method(df):
  K = range(2,10)
  silhouette_avg = []
  opt_k = 0
  sil_k = {}
  for k in K:
    # initialise kmeans
    kmediodModel = KMedoids(n_clusters=k)
    kmediodModel.fit(df)
    cluster_labels=kmediodModel.labels_
    #print(cluster_labels)
    # silhouette score
    sil_score = silhouette_score(df, cluster_labels)
    silhouette_avg.append(sil_score)
    sil_k[k] = sil_score
  plt.plot(K, silhouette_avg, 'bx-')
  plt.xlabel('Values of K') 
  plt.ylabel('Silhouette score') 
  plt.title('Silhouette analysis For Optimal k')
  plt.show()
  for key, value in sil_k.items(): 
         if max(silhouette_avg) == value: 
             opt_k = key
        
  # choose the optimum K
  return opt_k

# %%
opt_k_sil = K_sil_method(CC_df_std)

# %%
print("The optimal K using silhoutte score: ", opt_k_sil)
# Out:
# The optimal K using silhoutte score:  3

# %%
def elbow_method(df):
  distortions = []
  K = range(1,10)
  opt_k = 0
  for k in K:
      kmediodModel = KMedoids(n_clusters=k)
      kmediodModel.fit(df)
      cluster_labels=kmediodModel.labels_      
      distortions.append((kmeanModel.inertia_)/k)
  #print(len(distortions)-1)
  for i in range (1, len(distortions)-1):
   # print(i)
    if (distortions[i]-distortions[i+1])/(distortions[i-1]-distortions[i]) > 0.4:
      opt_k = i
   #   print(opt_k)
      break
  #print(distortions)
  plt.figure(figsize=(16,8))
  plt.plot(K, distortions, 'bx-')
  plt.xlabel('k')
  plt.ylabel('Distortion')
  plt.title('The Elbow Method showing the optimal k')
  plt.show()
  return opt_k

# %%
opt_k_elbow = elbow_method(CC_df_std)

# %%
print("The optimal K using elbow method: ", opt_k_elbow)
# Out:
# The optimal K using elbow method:  2

# %% [markdown]
# >> ### 3.2.2. Applying KMediods Clustering using optimal K

# %%
CC_df_k = CC_df.copy()
kmediodModel = KMedoids(n_clusters=opt_k_elbow)
kmediodModel.fit(CC_df_std)
cluster_labels=kmediodModel.labels_
labels = kmeanModel.labels_
CC_df_k['clusters'] = labels

# %%
CC_df_k

# %%
for c in CC_df_k:
    grid= sns.FacetGrid(CC_df_k, col='clusters')
    grid.map(plt.hist, c)

# %%
silhouette_score(CC_df_std, CC_df_k['clusters'], metric='euclidean')
# Out:
# 0.15146192527871521

# %% [markdown]
# >> ### 3.2.3. KMediods Clustering using PCA

# %%
CC_df_std_nor = normalize(CC_df_std)
pca = PCA(n_components = 2).fit(CC_df_std_nor)
df_pca  = pca.fit_transform(CC_df_std_nor)

# %%
pca_df = pd.DataFrame(df_pca, columns = ["PCA1", "PCA2"])
pca_df
# Out:
#           PCA1      PCA2
# 0    -0.481788 -0.692991
# 1    -0.537375  0.527808
# 2     0.320760  0.265223
# 3    -0.562994 -0.503868
# 4     0.320512 -0.254471
# ...        ...       ...
# 8631 -0.214325 -0.267827
# 8632  0.320251 -0.195203
# 8633  0.183536 -0.245043
# 8634 -0.307306 -0.176105
# 8635  0.008883  0.091170
#
# [8636 rows x 2 columns]

# %%
pca_df.shape
#columns.shape
# Out:
# (8636, 2)

# %%
kmediodModel = KMedoids(n_clusters=opt_k_elbow)
labels = kmediodModel.fit_predict(pca_df)
plt.scatter(pca_df['PCA1'], pca_df['PCA2'],
            c = labels) 
plt.show()

# %%
silhouette_score(pca_df, labels, metric='euclidean')
# Out:
# 0.4504935145152485

# %% [markdown]
# >> ### 3.2.4. KMediods Clustering using KernelPCA

# %%
CC_df_std_nor = normalize(CC_df_std)
Kpca = KernelPCA(n_components = 2, kernel = 'rbf').fit(CC_df_std_nor)
df_Kpca  = Kpca.fit_transform(CC_df_std_nor)

# %%
Kpca_df = pd.DataFrame(df_Kpca, columns = ["PCA1", "PCA2"])
Kpca_df
# Out:
#           PCA1      PCA2
# 0    -0.158098 -0.226071
# 1    -0.172392  0.172719
# 2     0.104427  0.086621
# 3    -0.185598 -0.164991
# 4     0.105177 -0.082704
# ...        ...       ...
# 8631 -0.068386 -0.086018
# 8632  0.104202 -0.062359
# 8633  0.060031 -0.078151
# 8634 -0.098268 -0.055736
# 8635  0.003478  0.029934
#
# [8636 rows x 2 columns]

# %%
Kpca_df.shape
#columns.shape
# Out:
# (8636, 2)

# %%
kmediodModel = KMedoids(n_clusters=opt_k_elbow)
labels = kmediodModel.fit_predict(Kpca_df)
plt.scatter(Kpca_df['PCA1'], Kpca_df['PCA2'],
            c = labels) 
plt.show()

# %%
silhouette_score(Kpca_df, labels, metric='euclidean')
# Out:
# 0.451372957612939

# %% [markdown]
# >> ### 3.1.5. KMediods Clustering using TSNE

# %%
CC_df_std_nor = normalize(CC_df_std)
tsne = TSNE(n_components=2, verbose=1, perplexity=40, n_iter=300)
df_tsne = tsne.fit_transform(CC_df_std_nor)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/manifold/_t_sne.py:783: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/manifold/_t_sne.py:793: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   FutureWarning,
# [t-SNE] Computing 121 nearest neighbors...
# [t-SNE] Indexed 8636 samples in 0.000s...
# [t-SNE] Computed neighbors for 8636 samples in 1.942s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 8636
# [t-SNE] Computed conditional probabilities for sample 2000 / 8636
# [t-SNE] Computed conditional probabilities for sample 3000 / 8636
# [t-SNE] Computed conditional probabilities for sample 4000 / 8636
# [t-SNE] Computed conditional probabilities for sample 5000 / 8636
# [t-SNE] Computed conditional probabilities for sample 6000 / 8636
# [t-SNE] Computed conditional probabilities for sample 7000 / 8636
# [t-SNE] Computed conditional probabilities for sample 8000 / 8636
# [t-SNE] Computed conditional probabilities for sample 8636 / 8636
# [t-SNE] Mean sigma: 0.161981
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 80.978790
# [t-SNE] KL divergence after 300 iterations: 2.421181

# %%
tsne_df = pd.DataFrame(df_tsne, columns = ["TSNE1", "TSNE2"])
tsne_df
# Out:
#          TSNE1      TSNE2
# 0     2.470503   3.961300
# 1    -1.296013   4.869562
# 2     0.162464  -0.898593
# 3    -7.990682  -3.982497
# 4    -2.679890  -8.914809
# ...        ...        ...
# 8631  3.996859   9.180352
# 8632  8.300158   7.254403
# 8633  7.490649   7.627518
# 8634  2.345029  10.556466
# 8635  3.260776   9.411744
#
# [8636 rows x 2 columns]

# %%
kMediodModel = KMedoids(n_clusters=3)
labels = kMediodModel.fit_predict(tsne_df)
plt.scatter(tsne_df['TSNE1'], tsne_df['TSNE2'],
            c = labels) 
plt.show()

# %%
silhouette_score(tsne_df, labels, metric='euclidean')

# %% [markdown]
# > ## 3.3. Hierarchical methods

# %% [markdown]
# >> ### 3.3.1. Choosing metric and method using pdist

# %%
links = ['ward', 'complete', 'average', 'single', 'weighted', 'centroid', 'median']
metrics = ['braycurtis', 'canberra', 'chebyshev', 'cityblock', 'correlation',
        'cosine', 'dice', 'euclidean', 'hamming', 'jaccard',
        'kulsinski', 'mahalanobis', 'matching', 'minkowski', 'rogerstanimoto',
        'russellrao', 'seuclidean', 'sokalmichener', 'sokalsneath', 'sqeuclidean']

# %%
columns = CC_df_std.columns
met_lin = {}
for metric in metrics:
  for link in links:
    if link == 'ward' and metric != 'euclidean':
            pass
    elif link == 'centroid' and metric != 'euclidean':
        pass
    elif link == 'median' and metric != 'euclidean':
        pass
    else:
      Z = shc.linkage(CC_df_std[columns], metric = metric, method = link)
      c, cop_dist = shc.cophenet(Z, distance.pdist(CC_df_std[columns]))
      if c > 0.8:
        key = metric + " + " + link
        met_lin [key] = c
        print("Metric: "+metric + " and Link: "+link+ " correlation score: "+str(c))
# Out:
# Metric: chebyshev and Link: complete correlation score: 0.8292055097753697
# Metric: chebyshev and Link: average correlation score: 0.8704793472940504
# Metric: chebyshev and Link: single correlation score: 0.8448357374035694
# Metric: chebyshev and Link: weighted correlation score: 0.8052587349459928
# Metric: cityblock and Link: average correlation score: 0.8305781964840179
# /usr/local/lib/python3.7/dist-packages/scipy/cluster/hierarchy.py:1699: RuntimeWarning: invalid value encountered in double_scalars
#   c = numerator.sum() / np.sqrt((denomA.sum() * denomB.sum()))
# Metric: euclidean and Link: complete correlation score: 0.8201186937921817
# Metric: euclidean and Link: average correlation score: 0.8810566943599851
# Metric: euclidean and Link: single correlation score: 0.8439715406337083
# Metric: euclidean and Link: centroid correlation score: 0.8732883923310477
# Metric: minkowski and Link: complete correlation score: 0.8201186937921817
# Metric: minkowski and Link: average correlation score: 0.881056694359985
# Metric: minkowski and Link: single correlation score: 0.8439715406337082
# Metric: seuclidean and Link: complete correlation score: 0.820118693792184
# Metric: seuclidean and Link: average correlation score: 0.881056694359987
# Metric: seuclidean and Link: single correlation score: 0.8439715406337124
# Metric: sqeuclidean and Link: average correlation score: 0.8037717787416976

# %%
max(met_lin.values())
met_lin.values()
# Out:
# dict_values([0.8292055097753697, 0.8704793472940504, 0.8448357374035694, 0.8052587349459928, 0.8305781964840179, 0.8201186937921817, 0.8810566943599851, 0.8439715406337083, 0.8732883923310477, 0.8201186937921817, 0.881056694359985, 0.8439715406337082, 0.820118693792184, 0.881056694359987, 0.8439715406337124, 0.8037717787416976])

# %%
for key, value in met_lin.items(): 
    if  value == max(met_lin.values()): 
        bestMethod=key
        break 
print("Best Method is:" + key + " with score: "+str(value))
# Out:
# Best Method is:seuclidean + average with score: 0.881056694359987

# %% [markdown]
# >> ### 3.3.2. Choosing optimal K

# %% [markdown]
# >>> #### 3.3.2.1. Choosing number of clusters using Dendrogram

# %%
plt.figure(figsize=(10, 7))
plt.title("Dendrogram")
dend = shc.dendrogram(shc.linkage(y=CC_df_std , method='average', metric='euclidean'))

# %% [markdown]
# >>> #### 3.3.2.2. Choosing number of clusters using Silhoutte score

# %%
def K_sil_agg_method(df):
  K = range(2,10)
  silhouette_avg = []
  opt_k = 0
  sil_k = {}
  for k in K:
    # initialize agg clustering 
    AggClusterModel = AgglomerativeClustering(n_clusters=k)
    AggClusterModel.fit(df)
    cluster_labels=AggClusterModel.labels_
    #print(cluster_labels)
    # silhouette score
    sil_score = silhouette_score(df, cluster_labels)
    silhouette_avg.append(sil_score)
    if k != 2:
      sil_k[k] = sil_score
  plt.plot(K, silhouette_avg, 'bx-')
  plt.xlabel('Values of K') 
  plt.ylabel('Silhouette score') 
  plt.title('Silhouette analysis For Optimal k')
  plt.show()
  for key, value in sil_k.items(): 
   #print(key)
    if value == max(sil_k.values()): 
        opt_k = key
  #print(sil_k)
  # choose the optimum K
  return opt_k

# %%
opt_agg_k = K_sil_agg_method(CC_df_std)

# %%
print("Optimal  number of clustering using sil score is: ", opt_agg_k)
# Out:
# Optimal  number of clustering using sil score is:  6

# %% [markdown]
# > ### 3.3.2. Applyin AggloAgglomerativeClustering with optimal K = 6, method = average and metric = eculidean

# %%
CC_df_agg = CC_df.copy()
AggClusterModel = AgglomerativeClustering(n_clusters=opt_agg_k, affinity = 'euclidean', linkage = 'average')
AggClusterModel.fit(CC_df_std)
cluster_labels=AggClusterModel.labels_
CC_df_agg['clusters'] = cluster_labels

# %%
CC_df_agg
# Out:
#           BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0       40.900749           0.818182      95.40              0.00
# 1     3202.467416           0.909091       0.00              0.00
# 2     2495.148862           1.000000     773.17            773.17
# 3      817.714335           1.000000      16.00             16.00
# 4     1809.828751           1.000000    1333.28              0.00
# ...           ...                ...        ...               ...
# 8631     5.871712           0.500000      20.90             20.90
# 8632    28.493517           1.000000     291.12              0.00
# 8633    23.398673           0.833333     144.40              0.00
# 8634    13.457564           0.833333       0.00              0.00
# 8635   372.708075           0.666667    1093.25           1093.25
#
#       INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                      95.40      0.000000             0.166667
# 1                       0.00   6442.945483             0.000000
# 2                       0.00      0.000000             1.000000
# 3                       0.00      0.000000             0.083333
# 4                    1333.28      0.000000             0.666667
# ...                      ...           ...                  ...
# 8631                    0.00      0.000000             0.166667
# 8632                  291.12      0.000000             1.000000
# 8633                  144.40      0.000000             0.833333
# 8634                    0.00     36.558778             0.000000
# 8635                    0.00    127.040008             0.666667
#
#       ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# 0                       0.000000                          0.083333
# 1                       0.000000                          0.000000
# 2                       1.000000                          0.000000
# 3                       0.083333                          0.000000
# 4                       0.000000                          0.583333
# ...                          ...                               ...
# 8631                    0.166667                          0.000000
# 8632                    0.000000                          0.833333
# 8633                    0.000000                          0.666667
# 8634                    0.000000                          0.000000
# 8635                    0.666667                          0.000000
#
#       CASH_ADVANCE_FREQUENCY  CASH_ADVANCE_TRX  PURCHASES_TRX  CREDIT_LIMIT  \
# 0                   0.000000                 0              2        1000.0
# 1                   0.250000                 4              0        7000.0
# 2                   0.000000                 0             12        7500.0
# 3                   0.000000                 0              1        1200.0
# 4                   0.000000                 0              8        1800.0
# ...                      ...               ...            ...           ...
# 8631                0.000000                 0              1         500.0
# 8632                0.000000                 0              6        1000.0
# 8633                0.000000                 0              5        1000.0
# 8634                0.166667                 2              0         500.0
# 8635                0.333333                 2             23        1200.0
#
#          PAYMENTS  MINIMUM_PAYMENTS  PRC_FULL_PAYMENT  TENURE  clusters
# 0      201.802084        139.509787          0.000000      12         1
# 1     4103.032597       1072.340217          0.222222      12         1
# 2      622.066742        627.284787          0.000000      12         1
# 3      678.334763        244.791237          0.000000      12         1
# 4     1400.057770       2407.246035          0.000000      12         1
# ...           ...               ...               ...     ...       ...
# 8631    58.644883         43.473717          0.000000       6         1
# 8632   325.594462         48.886365          0.500000       6         1
# 8633    81.270775         82.418369          0.250000       6         1
# 8634    52.549959         55.755628          0.250000       6         1
# 8635    63.165404         88.288956          0.000000       6         1
#
# [8636 rows x 18 columns]

# %%
silhouette_score(CC_df_std, CC_df_agg['clusters'], metric='euclidean')
# Out:
# 0.7803420960043396

# %%
CC_df_agg = CC_df.copy()
AggClusterModel = AgglomerativeClustering(n_clusters=6, affinity = 'euclidean', linkage = 'average')
AggClusterModel.fit(CC_df_std)
cluster_labels=AggClusterModel.labels_
CC_df_agg['clusters'] = cluster_labels

# %%
CC_df_agg
# Out:
#           BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0       40.900749           0.818182      95.40              0.00
# 1     3202.467416           0.909091       0.00              0.00
# 2     2495.148862           1.000000     773.17            773.17
# 3      817.714335           1.000000      16.00             16.00
# 4     1809.828751           1.000000    1333.28              0.00
# ...           ...                ...        ...               ...
# 8631     5.871712           0.500000      20.90             20.90
# 8632    28.493517           1.000000     291.12              0.00
# 8633    23.398673           0.833333     144.40              0.00
# 8634    13.457564           0.833333       0.00              0.00
# 8635   372.708075           0.666667    1093.25           1093.25
#
#       INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                      95.40      0.000000             0.166667
# 1                       0.00   6442.945483             0.000000
# 2                       0.00      0.000000             1.000000
# 3                       0.00      0.000000             0.083333
# 4                    1333.28      0.000000             0.666667
# ...                      ...           ...                  ...
# 8631                    0.00      0.000000             0.166667
# 8632                  291.12      0.000000             1.000000
# 8633                  144.40      0.000000             0.833333
# 8634                    0.00     36.558778             0.000000
# 8635                    0.00    127.040008             0.666667
#
#       ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# 0                       0.000000                          0.083333
# 1                       0.000000                          0.000000
# 2                       1.000000                          0.000000
# 3                       0.083333                          0.000000
# 4                       0.000000                          0.583333
# ...                          ...                               ...
# 8631                    0.166667                          0.000000
# 8632                    0.000000                          0.833333
# 8633                    0.000000                          0.666667
# 8634                    0.000000                          0.000000
# 8635                    0.666667                          0.000000
#
#       CASH_ADVANCE_FREQUENCY  CASH_ADVANCE_TRX  PURCHASES_TRX  CREDIT_LIMIT  \
# 0                   0.000000                 0              2        1000.0
# 1                   0.250000                 4              0        7000.0
# 2                   0.000000                 0             12        7500.0
# 3                   0.000000                 0              1        1200.0
# 4                   0.000000                 0              8        1800.0
# ...                      ...               ...            ...           ...
# 8631                0.000000                 0              1         500.0
# 8632                0.000000                 0              6        1000.0
# 8633                0.000000                 0              5        1000.0
# 8634                0.166667                 2              0         500.0
# 8635                0.333333                 2             23        1200.0
#
#          PAYMENTS  MINIMUM_PAYMENTS  PRC_FULL_PAYMENT  TENURE  clusters
# 0      201.802084        139.509787          0.000000      12         1
# 1     4103.032597       1072.340217          0.222222      12         1
# 2      622.066742        627.284787          0.000000      12         1
# 3      678.334763        244.791237          0.000000      12         1
# 4     1400.057770       2407.246035          0.000000      12         1
# ...           ...               ...               ...     ...       ...
# 8631    58.644883         43.473717          0.000000       6         1
# 8632   325.594462         48.886365          0.500000       6         1
# 8633    81.270775         82.418369          0.250000       6         1
# 8634    52.549959         55.755628          0.250000       6         1
# 8635    63.165404         88.288956          0.000000       6         1
#
# [8636 rows x 18 columns]

# %%
silhouette_score(CC_df_std, CC_df_agg['clusters'], metric='euclidean')
# Out:
# 0.7803420960043396

# %%
CC_df_agg = CC_df.copy()
AggClusterModel = AgglomerativeClustering(n_clusters=4, affinity = 'euclidean', linkage = 'average')
AggClusterModel.fit(CC_df_std)
cluster_labels=AggClusterModel.labels_
CC_df_agg['clusters'] = cluster_labels

# %%
CC_df_agg
# Out:
#           BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0       40.900749           0.818182      95.40              0.00
# 1     3202.467416           0.909091       0.00              0.00
# 2     2495.148862           1.000000     773.17            773.17
# 3      817.714335           1.000000      16.00             16.00
# 4     1809.828751           1.000000    1333.28              0.00
# ...           ...                ...        ...               ...
# 8631     5.871712           0.500000      20.90             20.90
# 8632    28.493517           1.000000     291.12              0.00
# 8633    23.398673           0.833333     144.40              0.00
# 8634    13.457564           0.833333       0.00              0.00
# 8635   372.708075           0.666667    1093.25           1093.25
#
#       INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                      95.40      0.000000             0.166667
# 1                       0.00   6442.945483             0.000000
# 2                       0.00      0.000000             1.000000
# 3                       0.00      0.000000             0.083333
# 4                    1333.28      0.000000             0.666667
# ...                      ...           ...                  ...
# 8631                    0.00      0.000000             0.166667
# 8632                  291.12      0.000000             1.000000
# 8633                  144.40      0.000000             0.833333
# 8634                    0.00     36.558778             0.000000
# 8635                    0.00    127.040008             0.666667
#
#       ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# 0                       0.000000                          0.083333
# 1                       0.000000                          0.000000
# 2                       1.000000                          0.000000
# 3                       0.083333                          0.000000
# 4                       0.000000                          0.583333
# ...                          ...                               ...
# 8631                    0.166667                          0.000000
# 8632                    0.000000                          0.833333
# 8633                    0.000000                          0.666667
# 8634                    0.000000                          0.000000
# 8635                    0.666667                          0.000000
#
#       CASH_ADVANCE_FREQUENCY  CASH_ADVANCE_TRX  PURCHASES_TRX  CREDIT_LIMIT  \
# 0                   0.000000                 0              2        1000.0
# 1                   0.250000                 4              0        7000.0
# 2                   0.000000                 0             12        7500.0
# 3                   0.000000                 0              1        1200.0
# 4                   0.000000                 0              8        1800.0
# ...                      ...               ...            ...           ...
# 8631                0.000000                 0              1         500.0
# 8632                0.000000                 0              6        1000.0
# 8633                0.000000                 0              5        1000.0
# 8634                0.166667                 2              0         500.0
# 8635                0.333333                 2             23        1200.0
#
#          PAYMENTS  MINIMUM_PAYMENTS  PRC_FULL_PAYMENT  TENURE  clusters
# 0      201.802084        139.509787          0.000000      12         0
# 1     4103.032597       1072.340217          0.222222      12         0
# 2      622.066742        627.284787          0.000000      12         0
# 3      678.334763        244.791237          0.000000      12         0
# 4     1400.057770       2407.246035          0.000000      12         0
# ...           ...               ...               ...     ...       ...
# 8631    58.644883         43.473717          0.000000       6         0
# 8632   325.594462         48.886365          0.500000       6         0
# 8633    81.270775         82.418369          0.250000       6         0
# 8634    52.549959         55.755628          0.250000       6         0
# 8635    63.165404         88.288956          0.000000       6         0
#
# [8636 rows x 18 columns]

# %%
silhouette_score(CC_df_std, CC_df_agg['clusters'], metric='euclidean')
# Out:
# 0.8047854548225128

# %% [markdown]
# > ## 3.4. DBSCAN

# %% [markdown]
# >> ### 3.4.1. Choosing eps range using Nearest Neighbour

# %%
def NN_eps (df):
  NN_model = NearestNeighbors(n_neighbors=2).fit(df)
  distances, indices = NN_model.kneighbors(df)
  distances = np.sort(distances, axis=0)
  distances = distances[:,1]
  plt.figure(figsize=(20,10))
  plt.plot(distances)
  plt.title('K-distance Graph',fontsize=20)
  plt.xlabel('Data Points sorted by distance',fontsize=14)
  plt.ylabel('Epsilon',fontsize=14)
  plt.show()

# %%
NN_eps(CC_df_std)

# %% [markdown]
# from the graph we can conculde that most of points (almost 8000) is under eps distance of 2

# %%
eps_range = np.arange(0.1, 2, 0.2)

# %% [markdown]
# >> ### 3.4.2. Choosing eps and minPoints

# %%
def eps_minPoint(df, eps_range):
  silhouette_avg = []
  sil_eps_p = {}
  for eps in eps_range:
    for minPoints in range (3, 10): # minPoint at least  = 3
      dbscan_model = DBSCAN(eps = eps, min_samples = minPoints).fit(df)
      cluster_labels=dbscan_model.labels_
      sil_score = silhouette_score(df, cluster_labels)
      silhouette_avg.append(sil_score)
      key = str(eps) +" and "+ str(minPoints)
      sil_eps_p[key] = sil_score
      print("Eps: "+str(eps)+", minPoints: "+str(minPoints) + ", Score: " +str(sil_score)+ ", number of clusters: ", str(len(set(dbscan_model.labels_))))
  for key, value in sil_eps_p.items(): 
    if value == max(silhouette_avg): 
        print ("Optimum eps and minPoints: ", key)

# %%
eps_minPoint(CC_df_std, eps_range)
# Out:
# Eps: 0.1, minPoints: 3, Score: -0.4689633985711107, number of clusters:  42
# Eps: 0.1, minPoints: 4, Score: -0.4195692899675594, number of clusters:  23
# Eps: 0.1, minPoints: 5, Score: -0.3737304348974619, number of clusters:  12
# Eps: 0.1, minPoints: 6, Score: -0.2750774407861322, number of clusters:  6
# Eps: 0.1, minPoints: 7, Score: -0.25366918294691654, number of clusters:  4
# Eps: 0.1, minPoints: 8, Score: -0.25090328181425725, number of clusters:  3
# Eps: 0.1, minPoints: 9, Score: -0.25124562443919085, number of clusters:  3
# Eps: 0.30000000000000004, minPoints: 3, Score: -0.47800400639962526, number of clusters:  111
# Eps: 0.30000000000000004, minPoints: 4, Score: -0.42545050596702805, number of clusters:  50
# Eps: 0.30000000000000004, minPoints: 5, Score: -0.4187151511195021, number of clusters:  39
# Eps: 0.30000000000000004, minPoints: 6, Score: -0.4257845119771976, number of clusters:  32
# Eps: 0.30000000000000004, minPoints: 7, Score: -0.412799048354344, number of clusters:  22
# Eps: 0.30000000000000004, minPoints: 8, Score: -0.4041543763287258, number of clusters:  17
# Eps: 0.30000000000000004, minPoints: 9, Score: -0.3967722299164506, number of clusters:  14
# Eps: 0.5000000000000001, minPoints: 3, Score: -0.5244811903255837, number of clusters:  129
# Eps: 0.5000000000000001, minPoints: 4, Score: -0.5102458511113763, number of clusters:  63
# Eps: 0.5000000000000001, minPoints: 5, Score: -0.465117752115066, number of clusters:  37
# Eps: 0.5000000000000001, minPoints: 6, Score: -0.40228690465403466, number of clusters:  21
# Eps: 0.5000000000000001, minPoints: 7, Score: -0.385451914963475, number of clusters:  17
# Eps: 0.5000000000000001, minPoints: 8, Score: -0.3189461860956522, number of clusters:  12
# Eps: 0.5000000000000001, minPoints: 9, Score: -0.3259039450623435, number of clusters:  13
# Eps: 0.7000000000000001, minPoints: 3, Score: -0.516547422399089, number of clusters:  94
# Eps: 0.7000000000000001, minPoints: 4, Score: -0.4962803943320141, number of clusters:  49
# Eps: 0.7000000000000001, minPoints: 5, Score: -0.43770103238013724, number of clusters:  26
# Eps: 0.7000000000000001, minPoints: 6, Score: -0.39628057386883997, number of clusters:  19
# Eps: 0.7000000000000001, minPoints: 7, Score: -0.4171858369582397, number of clusters:  15
# Eps: 0.7000000000000001, minPoints: 8, Score: -0.39169298085216375, number of clusters:  14
# Eps: 0.7000000000000001, minPoints: 9, Score: -0.2970440206560081, number of clusters:  11
# Eps: 0.9000000000000001, minPoints: 3, Score: -0.4613607460814622, number of clusters:  73
# Eps: 0.9000000000000001, minPoints: 4, Score: -0.42155360008852766, number of clusters:  34
# Eps: 0.9000000000000001, minPoints: 5, Score: -0.37945823993345906, number of clusters:  18
# Eps: 0.9000000000000001, minPoints: 6, Score: -0.29368024503465107, number of clusters:  10
# Eps: 0.9000000000000001, minPoints: 7, Score: 0.002823892227602225, number of clusters:  6
# Eps: 0.9000000000000001, minPoints: 8, Score: -0.06540444057131069, number of clusters:  6
# Eps: 0.9000000000000001, minPoints: 9, Score: -0.08810964496796495, number of clusters:  10
# Eps: 1.1000000000000003, minPoints: 3, Score: -0.37535783525839655, number of clusters:  56
# Eps: 1.1000000000000003, minPoints: 4, Score: -0.2278227803762245, number of clusters:  21
# Eps: 1.1000000000000003, minPoints: 5, Score: -0.19075700839565443, number of clusters:  12
# Eps: 1.1000000000000003, minPoints: 6, Score: -0.14024688049405978, number of clusters:  7
# Eps: 1.1000000000000003, minPoints: 7, Score: -0.14447761969489614, number of clusters:  6
# Eps: 1.1000000000000003, minPoints: 8, Score: -0.1300966058827394, number of clusters:  6
# Eps: 1.1000000000000003, minPoints: 9, Score: -0.12448726756428644, number of clusters:  7
# Eps: 1.3000000000000003, minPoints: 3, Score: -0.23311242542435692, number of clusters:  32
# Eps: 1.3000000000000003, minPoints: 4, Score: -0.10035452239120227, number of clusters:  13
# Eps: 1.3000000000000003, minPoints: 5, Score: -0.022098544138090346, number of clusters:  7
# Eps: 1.3000000000000003, minPoints: 6, Score: 0.07396810580079453, number of clusters:  4
# Eps: 1.3000000000000003, minPoints: 7, Score: 0.07598173864044745, number of clusters:  4
# Eps: 1.3000000000000003, minPoints: 8, Score: 0.13868725131551515, number of clusters:  3
# Eps: 1.3000000000000003, minPoints: 9, Score: 0.2718209785631869, number of clusters:  2
# Eps: 1.5000000000000004, minPoints: 3, Score: -0.10044136048212002, number of clusters:  22
# Eps: 1.5000000000000004, minPoints: 4, Score: 0.06416386892038223, number of clusters:  10
# Eps: 1.5000000000000004, minPoints: 5, Score: -0.0023840810774559355, number of clusters:  8
# Eps: 1.5000000000000004, minPoints: 6, Score: 0.02564049975271129, number of clusters:  4
# Eps: 1.5000000000000004, minPoints: 7, Score: 0.2627808976968818, number of clusters:  3
# Eps: 1.5000000000000004, minPoints: 8, Score: 0.30215610871656123, number of clusters:  3
# Eps: 1.5000000000000004, minPoints: 9, Score: 0.3352939022170549, number of clusters:  2
# Eps: 1.7000000000000004, minPoints: 3, Score: 0.014839762145478878, number of clusters:  14
# Eps: 1.7000000000000004, minPoints: 4, Score: 0.07018768015221855, number of clusters:  6
# Eps: 1.7000000000000004, minPoints: 5, Score: 0.39328868126483263, number of clusters:  3
# Eps: 1.7000000000000004, minPoints: 6, Score: 0.4014485895989403, number of clusters:  2
# Eps: 1.7000000000000004, minPoints: 7, Score: 0.398886467869937, number of clusters:  2
# Eps: 1.7000000000000004, minPoints: 8, Score: 0.39525430310116394, number of clusters:  2
# Eps: 1.7000000000000004, minPoints: 9, Score: 0.3309185031165114, number of clusters:  3
# Eps: 1.9000000000000004, minPoints: 3, Score: 0.11487195616987556, number of clusters:  9
# Eps: 1.9000000000000004, minPoints: 4, Score: 0.18062136378642227, number of clusters:  4
# Eps: 1.9000000000000004, minPoints: 5, Score: 0.4587942262610554, number of clusters:  2
# Eps: 1.9000000000000004, minPoints: 6, Score: 0.4533564322937519, number of clusters:  2
# Eps: 1.9000000000000004, minPoints: 7, Score: 0.4468102514502899, number of clusters:  2
# Eps: 1.9000000000000004, minPoints: 8, Score: 0.4429980425010093, number of clusters:  2
# Eps: 1.9000000000000004, minPoints: 9, Score: 0.4384952983524236, number of clusters:  2
# Optimum eps and minPoints:  1.9000000000000004 and 5

# %% [markdown]
# >> ### 3.4.3. Applying DBSCAN

# %%
CC_df_dbscan = CC_df.copy()
eps = 1.9
minPoints = 5
dbscan_model = DBSCAN(eps = eps, min_samples = minPoints).fit(CC_df_std)
DBSCAN_labels=dbscan_model.labels_
CC_df_dbscan['clusters'] = DBSCAN_labels

# %%
silhouette_score(CC_df_std, DBSCAN_labels)
# Out:
# 0.4587942262610554

# %% [markdown]
# # 4. Anomaly Detection

# %% [markdown]
# > ## 4.1. Using DBSCAN

# %%
anomaly_df = CC_df[DBSCAN_labels==-1]

# %%
anomaly_df
# Out:
#            BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 5       627.260806           1.000000    7091.01           6402.63
# 20     6369.531318           1.000000    6359.95           5910.04
# 22     3800.151377           0.818182    4248.35           3454.56
# 29    12136.219960           1.000000    3038.01           1013.20
# 33     3517.101616           0.727273     547.28              0.00
# ...            ...                ...        ...               ...
# 8554   1382.936306           0.875000     336.00              0.00
# 8588    328.686581           1.000000    2806.78           2588.53
# 8605    181.891981           0.500000       0.00              0.00
# 8613    486.661842           0.833333    1898.88            939.09
# 8629   5967.475270           0.833333     214.55              0.00
#
#       INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 5                     688.38      0.000000             1.000000
# 20                    449.91    229.028245             1.000000
# 22                    793.79   7974.415626             1.000000
# 29                   2024.81   3183.583301             1.000000
# 33                    547.28      0.000000             1.000000
# ...                      ...           ...                  ...
# 8554                  336.00   4158.990631             0.875000
# 8588                  218.25      0.000000             0.857143
# 8605                    0.00   1865.191764             0.000000
# 8613                  959.79      0.000000             0.833333
# 8629                  214.55   8555.409326             0.833333
#
#       ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# 5                       1.000000                          1.000000
# 20                      0.916667                          1.000000
# 22                      0.083333                          0.916667
# 29                      0.166667                          1.000000
# 33                      0.000000                          1.000000
# ...                          ...                               ...
# 8554                    0.000000                          0.750000
# 8588                    0.714286                          0.285714
# 8605                    0.000000                          0.000000
# 8613                    0.666667                          0.666667
# 8629                    0.000000                          0.666667
#
#       CASH_ADVANCE_FREQUENCY  CASH_ADVANCE_TRX  PURCHASES_TRX  CREDIT_LIMIT  \
# 5                   0.000000                 0             64       13500.0
# 20                  0.333333                 6             92       11250.0
# 22                  0.333333                13             13        9000.0
# 29                  0.500000                10             64       13000.0
# 33                  0.000000                 0             14       11000.0
# ...                      ...               ...            ...           ...
# 8554                0.125000                 5              7        4000.0
# 8588                0.000000                 0             26        1200.0
# 8605                0.500000                10              0        2000.0
# 8613                0.000000                 0             24        1200.0
# 8629                0.666667                13              5        9000.0
#
#          PAYMENTS  MINIMUM_PAYMENTS  PRC_FULL_PAYMENT  TENURE
# 5     6354.314328        198.065894              1.00      12
# 20    2077.959051       1659.775075              0.00      12
# 22    9479.043842       1425.426525              0.00      12
# 29    4230.323491       3292.015030              0.00      12
# 33    8735.607835      17862.558310              0.00      12
# ...           ...               ...               ...     ...
# 8554   754.256439        681.059427              0.60       8
# 8588  1796.886852         93.017466              0.25       7
# 8605  4565.356495         88.057892              1.00       6
# 8613   669.039640        336.880119              0.50       6
# 8629   966.202912        861.949906              0.00       6
#
# [695 rows x 17 columns]

# %% [markdown]
# > ## 4.2. Using EM

# %%
GmmModel = GaussianMixture(n_components = 2, covariance_type = 'spherical', max_iter = 300, verbose = 1, tol = 0.00001)
GmmModel.fit(CC_df_std)
# Out:
# Initialization 0
#   Iteration 10
#   Iteration 20
#   Iteration 30
# Initialization converged: True
# GaussianMixture(covariance_type='spherical', max_iter=300, n_components=2,
#                 tol=1e-05, verbose=1)

# %%
CC_df_Gmm = CC_df.copy()
Gmmlabels = GmmModel.predict(CC_df_std)
Gmmscore = GmmModel.score_samples(CC_df_std)
CC_df_Gmm['labels'] = Gmmlabels
#CC_df_Gmm['scores'] = Gmmscore
CC_df_Gmm
# Out:
#           BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0       40.900749           0.818182      95.40              0.00
# 1     3202.467416           0.909091       0.00              0.00
# 2     2495.148862           1.000000     773.17            773.17
# 3      817.714335           1.000000      16.00             16.00
# 4     1809.828751           1.000000    1333.28              0.00
# ...           ...                ...        ...               ...
# 8631     5.871712           0.500000      20.90             20.90
# 8632    28.493517           1.000000     291.12              0.00
# 8633    23.398673           0.833333     144.40              0.00
# 8634    13.457564           0.833333       0.00              0.00
# 8635   372.708075           0.666667    1093.25           1093.25
#
#       INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                      95.40      0.000000             0.166667
# 1                       0.00   6442.945483             0.000000
# 2                       0.00      0.000000             1.000000
# 3                       0.00      0.000000             0.083333
# 4                    1333.28      0.000000             0.666667
# ...                      ...           ...                  ...
# 8631                    0.00      0.000000             0.166667
# 8632                  291.12      0.000000             1.000000
# 8633                  144.40      0.000000             0.833333
# 8634                    0.00     36.558778             0.000000
# 8635                    0.00    127.040008             0.666667
#
#       ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# 0                       0.000000                          0.083333
# 1                       0.000000                          0.000000
# 2                       1.000000                          0.000000
# 3                       0.083333                          0.000000
# 4                       0.000000                          0.583333
# ...                          ...                               ...
# 8631                    0.166667                          0.000000
# 8632                    0.000000                          0.833333
# 8633                    0.000000                          0.666667
# 8634                    0.000000                          0.000000
# 8635                    0.666667                          0.000000
#
#       CASH_ADVANCE_FREQUENCY  CASH_ADVANCE_TRX  PURCHASES_TRX  CREDIT_LIMIT  \
# 0                   0.000000                 0              2        1000.0
# 1                   0.250000                 4              0        7000.0
# 2                   0.000000                 0             12        7500.0
# 3                   0.000000                 0              1        1200.0
# 4                   0.000000                 0              8        1800.0
# ...                      ...               ...            ...           ...
# 8631                0.000000                 0              1         500.0
# 8632                0.000000                 0              6        1000.0
# 8633                0.000000                 0              5        1000.0
# 8634                0.166667                 2              0         500.0
# 8635                0.333333                 2             23        1200.0
#
#          PAYMENTS  MINIMUM_PAYMENTS  PRC_FULL_PAYMENT  TENURE  labels
# 0      201.802084        139.509787          0.000000      12       1
# 1     4103.032597       1072.340217          0.222222      12       1
# 2      622.066742        627.284787          0.000000      12       1
# 3      678.334763        244.791237          0.000000      12       1
# 4     1400.057770       2407.246035          0.000000      12       1
# ...           ...               ...               ...     ...     ...
# 8631    58.644883         43.473717          0.000000       6       0
# 8632   325.594462         48.886365          0.500000       6       0
# 8633    81.270775         82.418369          0.250000       6       0
# 8634    52.549959         55.755628          0.250000       6       0
# 8635    63.165404         88.288956          0.000000       6       0
#
# [8636 rows x 18 columns]

# %%
Gmmscore.shape
# Out:
# (8636,)

# %%
thresh = np.quantile(Gmmscore, 0.03)
print(thresh)
# Out:
# -35.426247704394115

# %%
outlier_df = CC_df_Gmm[Gmmscore<thresh]
outlier_df
# Out:
#            BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 33     3517.101616           0.727273     547.28              0.00
# 47     4931.331857           1.000000     901.42            646.07
# 64     2990.422186           0.909091    4523.27           1664.09
# 110   14224.115410           1.000000       0.00              0.00
# 111    2392.917738           1.000000   12462.44          12462.44
# ...            ...                ...        ...               ...
# 7963   2144.040539           1.000000       0.00              0.00
# 8039   2648.244646           1.000000       0.00              0.00
# 8141   3911.628474           0.875000       0.00              0.00
# 8250   3326.323283           1.000000    8209.77           2218.28
# 8548   2330.222764           1.000000    1320.00              0.00
#
#       INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 33                    547.28      0.000000             1.000000
# 47                    255.35   8530.648614             0.625000
# 64                   2859.18  27296.485760             0.666667
# 110                     0.00   4614.427403             0.000000
# 111                     0.00      0.000000             0.916667
# ...                      ...           ...                  ...
# 7963                    0.00  14127.466640             0.000000
# 8039                    0.00  10458.978150             0.000000
# 8141                    0.00  11951.903320             0.000000
# 8250                 5991.49      0.000000             1.000000
# 8548                 1320.00  14926.790590             0.428571
#
#       ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# 33                      0.000000                          1.000000
# 47                      0.375000                          0.250000
# 64                      0.500000                          0.583333
# 110                     0.000000                          0.000000
# 111                     0.916667                          0.000000
# ...                          ...                               ...
# 7963                    0.000000                          0.000000
# 8039                    0.000000                          0.000000
# 8141                    0.000000                          0.000000
# 8250                    0.416667                          1.000000
# 8548                    0.000000                          0.285714
#
#       CASH_ADVANCE_FREQUENCY  CASH_ADVANCE_TRX  PURCHASES_TRX  CREDIT_LIMIT  \
# 33                  0.000000                 0             14       11000.0
# 47                  0.875000                37              9       12000.0
# 64                  0.833333                27             33        7000.0
# 110                 0.333333                 9              0       19000.0
# 111                 0.000000                 0            217        2800.0
# ...                      ...               ...            ...           ...
# 7963                0.416667                23              0        3500.0
# 8039                1.000000               123              0        4000.0
# 8141                0.500000                40              0        7000.0
# 8250                0.000000                 0            130       10000.0
# 8548                0.571429                10              3       10000.0
#
#           PAYMENTS  MINIMUM_PAYMENTS  PRC_FULL_PAYMENT  TENURE  labels
# 33     8735.607835      17862.558310          0.000000      12       0
# 47     8113.297346       1012.415961          0.000000       8       0
# 64    28232.694460       1107.030803          0.454545      12       0
# 110    3066.614272       3406.258999          0.000000      12       0
# 111   11628.715570       2000.990921          0.000000      12       0
# ...            ...               ...               ...     ...     ...
# 7963  12571.814660        525.168936          0.300000      12       0
# 8039   9818.531412        665.888853          0.000000      12       0
# 8141   7918.877416        905.569605          0.166667       8       0
# 8250   1942.074765        702.905059          0.083333      12       0
# 8548   8157.666434        283.362434          0.200000       7       0
#
# [260 rows x 18 columns]

# %% [markdown]
# > ## 4.3. Using IsolatedForest

# %%
IsoForModel = IsolationForest(n_estimators = 100, max_samples = 'auto', contamination = 0.1, max_features = 1)
IsoForModel.fit(CC_df_std)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but IsolationForest was fitted with feature names
#   "X does not have valid feature names, but"
# IsolationForest(contamination=0.1, max_features=1)

# %%
IsoAnomlabels = IsoForModel.predict(CC_df_std)

# %%
anomaly_df = CC_df[IsoAnomlabels==-1]
anomaly_df
# Out:
#            BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 5       627.260806           1.000000    7091.01           6402.63
# 20     6369.531318           1.000000    6359.95           5910.04
# 22     3800.151377           0.818182    4248.35           3454.56
# 29    12136.219960           1.000000    3038.01           1013.20
# 33     3517.101616           0.727273     547.28              0.00
# ...            ...                ...        ...               ...
# 8603    376.547421           0.857143     520.00            280.00
# 8605    181.891981           0.500000       0.00              0.00
# 8609     11.294184           0.666667     155.00              0.00
# 8629   5967.475270           0.833333     214.55              0.00
# 8634     13.457564           0.833333       0.00              0.00
#
#       INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 5                     688.38      0.000000             1.000000
# 20                    449.91    229.028245             1.000000
# 22                    793.79   7974.415626             1.000000
# 29                   2024.81   3183.583301             1.000000
# 33                    547.28      0.000000             1.000000
# ...                      ...           ...                  ...
# 8603                  240.00   1178.402416             0.857143
# 8605                    0.00   1865.191764             0.000000
# 8609                  155.00      0.000000             0.666667
# 8629                  214.55   8555.409326             0.833333
# 8634                    0.00     36.558778             0.000000
#
#       ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# 5                       1.000000                          1.000000
# 20                      0.916667                          1.000000
# 22                      0.083333                          0.916667
# 29                      0.166667                          1.000000
# 33                      0.000000                          1.000000
# ...                          ...                               ...
# 8603                    0.142857                          0.714286
# 8605                    0.000000                          0.000000
# 8609                    0.000000                          0.500000
# 8629                    0.000000                          0.666667
# 8634                    0.000000                          0.000000
#
#       CASH_ADVANCE_FREQUENCY  CASH_ADVANCE_TRX  PURCHASES_TRX  CREDIT_LIMIT  \
# 5                   0.000000                 0             64       13500.0
# 20                  0.333333                 6             92       11250.0
# 22                  0.333333                13             13        9000.0
# 29                  0.500000                10             64       13000.0
# 33                  0.000000                 0             14       11000.0
# ...                      ...               ...            ...           ...
# 8603                0.714286                 9              7        1000.0
# 8605                0.500000                10              0        2000.0
# 8609                0.000000                 0              4        1000.0
# 8629                0.666667                13              5        9000.0
# 8634                0.166667                 2              0         500.0
#
#          PAYMENTS  MINIMUM_PAYMENTS  PRC_FULL_PAYMENT  TENURE
# 5     6354.314328        198.065894              1.00      12
# 20    2077.959051       1659.775075              0.00      12
# 22    9479.043842       1425.426525              0.00      12
# 29    4230.323491       3292.015030              0.00      12
# 33    8735.607835      17862.558310              0.00      12
# ...           ...               ...               ...     ...
# 8603   929.415656        103.927887              0.20       7
# 8605  4565.356495         88.057892              1.00       6
# 8609   149.588599         43.341698              0.50       6
# 8629   966.202912        861.949906              0.00       6
# 8634    52.549959         55.755628              0.25       6
#
# [864 rows x 17 columns]

# %% [markdown]
# # Final Model

# %% [markdown]
# using AgglomerativeClustering sith heighest silhoutte score and clusters = 6

# %%
cc_df_test_std = cc_df_test.copy()
columns = cc_df_test_std.columns
features = cc_df_test_std[columns]
cc_df_test_std[columns] = StandardScaler().fit_transform(features.values)

# %%
cc_df_test_label = cc_df_test.copy()
AggClusterModel = AgglomerativeClustering(n_clusters=6, affinity = 'euclidean', linkage = 'average')
labels = AggClusterModel.fit_predict(cc_df_test_std)
cc_df_test_label ['cluster'] = labels

# %%
cc_df_test_label
# Out:
#           BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 2263    19.112841           1.000000     504.20              0.00
# 6255   834.825957           1.000000       0.00              0.00
# 7316    29.466141           0.545455     149.00            149.00
# 2045   226.030380           1.000000     435.08            435.08
# 5253    38.160715           0.545455     340.00              0.00
# ...           ...                ...        ...               ...
# 705   1350.286625           1.000000     642.33            642.33
# 6500    82.902896           0.727273     430.43              0.00
# 7873   226.306461           0.363636       0.00              0.00
# 6652     9.153671           0.272727     126.60              0.00
# 5198   658.655200           1.000000     629.99            629.99
#
#       INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 2263                  504.20      0.000000             1.000000
# 6255                    0.00   1195.000251             0.000000
# 7316                    0.00      0.000000             0.083333
# 2045                    0.00      0.000000             0.916667
# 5253                  340.00      0.000000             0.500000
# ...                      ...           ...                  ...
# 705                     0.00      0.000000             0.500000
# 6500                  430.43      0.000000             0.500000
# 7873                    0.00    788.235661             0.000000
# 6652                  126.60      0.000000             0.500000
# 5198                    0.00      0.000000             0.083333
#
#       ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# 2263                    0.000000                          1.000000
# 6255                    0.000000                          0.000000
# 7316                    0.083333                          0.000000
# 2045                    0.916667                          0.000000
# 5253                    0.000000                          0.416667
# ...                          ...                               ...
# 705                     0.500000                          0.000000
# 6500                    0.000000                          0.416667
# 7873                    0.000000                          0.000000
# 6652                    0.000000                          0.416667
# 5198                    0.083333                          0.000000
#
#       CASH_ADVANCE_FREQUENCY  CASH_ADVANCE_TRX  PURCHASES_TRX  CREDIT_LIMIT  \
# 2263                0.000000                 0             20        1000.0
# 6255                0.250000                 6              0        1200.0
# 7316                0.000000                 0              1        1000.0
# 2045                0.000000                 0             15        7500.0
# 5253                0.000000                 0              6        5000.0
# ...                      ...               ...            ...           ...
# 705                 0.000000                 0             12        9000.0
# 6500                0.000000                 0             10        2500.0
# 7873                0.166667                 3              0        1200.0
# 6652                0.000000                 0              6        2900.0
# 5198                0.000000                 0              1        6000.0
#
#          PAYMENTS  MINIMUM_PAYMENTS  PRC_FULL_PAYMENT  TENURE  cluster
# 2263   476.370018        130.862225          0.727273      12        1
# 6255  1392.439311        221.752549          0.100000      12        1
# 7316   350.176472        215.215582          0.000000      12        1
# 2045  3796.014359        180.308803          0.200000      12        1
# 5253   888.221177        146.348596          1.000000      12        1
# ...           ...               ...               ...     ...      ...
# 705    323.683167        344.973051          0.000000      12        1
# 6500   315.075002         87.824996          0.083333      12        1
# 7873   184.701045        217.492643          0.000000      12        1
# 6652   134.386353         46.037748          0.000000      12        1
# 5198   353.862252        247.500183          0.000000      12        1
#
# [1728 rows x 18 columns]

# %% [markdown]
# #### Detecting if there are any anomalies

# %%
IsoForModel = IsolationForest(n_estimators = 100, max_samples = 'auto', contamination = 0.1, max_features = 1)
IsoForModel.fit(cc_df_test_std)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but IsolationForest was fitted with feature names
#   "X does not have valid feature names, but"
# IsolationForest(contamination=0.1, max_features=1)

# %%
IsoAnomlabels = IsoForModel.predict(cc_df_test_std)

# %%
anomaly_df = cc_df_test[IsoAnomlabels==-1]
anomaly_df
# Out:
#           BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 2517  6810.401782           1.000000     635.76            164.32
# 1458  3608.548972           0.900000    1664.02           1620.60
# 1063  4550.717687           1.000000    2094.99           1357.00
# 7998  1410.909779           1.000000     698.88              0.00
# 5440  8894.553534           1.000000     476.84            476.84
# ...           ...                ...        ...               ...
# 4058   889.090252           1.000000    9751.90           5896.76
# 4363  7558.010921           1.000000     365.26            188.56
# 3909   293.614532           0.857143     839.61            839.61
# 3732  5000.825577           1.000000    3310.39           3072.89
# 2098  4068.162699           1.000000    3387.47           1938.13
#
#       INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 2517                  471.44   3863.405310             0.916667
# 1458                   43.42   3899.963528             0.500000
# 1063                  737.99   2392.186586             1.000000
# 7998                  698.88    948.848018             1.000000
# 5440                    0.00   6098.490836             0.166667
# ...                      ...           ...                  ...
# 4058                 3855.14      0.000000             1.000000
# 4363                  176.70   4738.307540             0.500000
# 3909                    0.00   2018.794348             0.714286
# 3732                  237.50   2019.865472             0.750000
# 2098                 1449.34      0.000000             1.000000
#
#       ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# 2517                    0.083333                          0.916667
# 1458                    0.500000                          0.100000
# 1063                    0.500000                          1.000000
# 7998                    0.000000                          1.000000
# 5440                    0.166667                          0.000000
# ...                          ...                               ...
# 4058                    1.000000                          0.916667
# 4363                    0.083333                          0.416667
# 3909                    0.714286                          0.000000
# 3732                    0.666667                          0.333333
# 2098                    1.000000                          1.000000
#
#       CASH_ADVANCE_FREQUENCY  CASH_ADVANCE_TRX  PURCHASES_TRX  CREDIT_LIMIT  \
# 2517                0.250000                13             17       10000.0
# 1458                0.300000                 5             15        5000.0
# 1063                0.166667                 2             23        7600.0
# 7998                0.166667                 8             12        1200.0
# 5440                0.583333                16              3       12000.0
# ...                      ...               ...            ...           ...
# 4058                0.000000                 0            115        4500.0
# 4363                0.666667                25              9        8000.0
# 3909                0.857143                12             11        3000.0
# 3732                0.083333                 1             28        7500.0
# 2098                0.000000                 0             86        8500.0
#
#          PAYMENTS  MINIMUM_PAYMENTS  PRC_FULL_PAYMENT  TENURE
# 2517  3161.148768       3781.907645          0.000000      12
# 1458  1043.772722       1488.313908          0.000000      10
# 1063  3172.264416       1091.281356          0.000000      12
# 7998    79.578186      11795.280960          0.083333      12
# 5440  2163.376448       2871.461432          0.000000      12
# ...           ...               ...               ...     ...
# 4058  8418.403666        206.690230          0.666667      12
# 4363  3311.192387       4903.859993          0.000000      12
# 3909  2585.110269        102.177146          0.500000       7
# 3732  2633.433636       2412.441231          0.000000      12
# 2098  1312.481879       1245.153414          0.000000      12
#
# [173 rows x 17 columns]

# %% [markdown]
# #### Graph of 6 segments using PCA

# %%
CC_df_std_nor = normalize(cc_df_test_std)
Kpca = KernelPCA(n_components = 2, kernel = 'rbf').fit(CC_df_std_nor)
df_Kpca  = Kpca.fit_transform(CC_df_std_nor)

# %%
Kpca_df = pd.DataFrame(df_Kpca, columns = ["PCA1", "PCA2"])
Kpca_df
# Out:
#           PCA1      PCA2
# 0     0.203738 -0.140351
# 1    -0.261360 -0.028172
# 2    -0.153387 -0.188982
# 3     0.113717  0.052342
# 4     0.058932 -0.140944
# ...        ...       ...
# 1723 -0.009792  0.035608
# 1724 -0.008211 -0.264078
# 1725 -0.172870 -0.122585
# 1726 -0.021398 -0.175693
# 1727 -0.175406 -0.092243
#
# [1728 rows x 2 columns]

# %%
Kpca_df.shape
#columns.shape
# Out:
# (1728, 2)

# %%
labels = AggClusterModel.fit_predict(Kpca_df)
plt.scatter(Kpca_df['PCA1'], Kpca_df['PCA2'],
            c = labels) 
plt.show()

# %% [markdown]
# >### There are 6 Segements

# %% [markdown]
# >> #### Seg 1

# %% [markdown]
# -  Increased balances.
# - Average purchases, mainly one-off.
# - Low cash advance usage.
# - Increased balances compared to their purchases suggest that they tend to carry past balances; this conclusion is also indicated by increased usage of  their limit (balance to credit limit ratio).
# - They seem to pay a small amount of their due balance every month, as indicated by the low payments to statement balance ratio. Their ‘‘revolver’’ behavior is also suggested by the fact that they have the lowest percentage of months with full payment of their due balance.

# %% [markdown]
# >> #### Seg 2

# %% [markdown]
# - Highest cash advance usage in terms of frequency and amount of cash withdrawals.
# - Few purchases.
# - 85% of their total card spending is attributed to cash advances.
# - Highest monthly balance amounts.
# - They also present high limit usage.
# - they tend to carry past balances and pay only a part of their monthly  balances as indicated by the low frequency of full payments and the similarly low ratio of payments to balance.

# %% [markdown]
# >> #### Seg 3

# %% [markdown]
# - Highest purchases, in terms of frequency and volume.
# - One-off as well as installment purchases.
# - Moderate balances and limit usage.
# - Their spending is almost exclusively purchases since their cash advance usage is low.
# - Their high payments to balance ratio and frequency of full payments suggest a transactor behavior.

# %% [markdown]
# >> #### Seg 4

# %% [markdown]
# - Relatively low purchases.
# - Their spending is almost exclusively on installments.
# - Moderate balances.

# %% [markdown]
# >> #### Seg 5

# %% [markdown]
# - Lowest purchases and cash advance usage.
# - Lowest ratio of balance to credit limit.
# - Insignificant (remnant?) balances.

# %% [markdown]
# >> #### Seg6

# %% [markdown]
# - Increased purchases, including almost exclusively one-off purchases.
# - High-value but infrequent purchase transactions: their purchase frequency is
# relatively low; however, they have the largest average amount per purchase transaction.
# - Moderate balances and credit limit usage.
# - They present a transactor behavior.

# %% [markdown]
# ------
